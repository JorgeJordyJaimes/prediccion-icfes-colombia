# %% [markdown]
# # 1. CARGA DE DATOS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 500)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
## Carga de datos desde Dropbox

url = "https://www.dropbox.com/scl/fi/mbckz5ce5c5qke9330i4m/icfes.csv?rlkey=d9ipf96vuwbq6mmmjqnxfv3vw&st=ksckq0wg&dl=1"
icfes = pd.read_csv(url, sep=None, engine="python")

icfes.head(4)
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M           18/02/2002
# 1                 TI          COLOMBIA           M           28/06/2003
# 2                 TI          COLOMBIA           M            2/06/2001
# 3                 TI          COLOMBIA           M           26/04/2002
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# 2    20194  SB11201940255017      ESTUDIANTE              No         COLOMBIA
# 3    20194  SB11201940154799      ESTUDIANTE              Si         COLOMBIA
#
#   ESTU_ETNIA ESTU_DEPTO_RESIDE ESTU_COD_RESIDE_DEPTO    ESTU_MCPIO_RESIDE  \
# 0          -         MAGDALENA                    47            SANTA ANA
# 1          -            BOGOTÁ                    11          BOGOTÁ D.C.
# 2          -           BOLIVAR                    13  CARTAGENA DE INDIAS
# 3    Ninguno            BOGOTÁ                    11          BOGOTÁ D.C.
#
#   ESTU_COD_RESIDE_MCPIO FAMI_ESTRATOVIVIENDA FAMI_PERSONASHOGAR  \
# 0                 47707            Estrato 3              5 a 6
# 1                 11001            Estrato 3            9 o más
# 2                 13001            Estrato 1              5 a 6
# 3                 11001            Estrato 3              3 a 4
#
#   FAMI_CUARTOSHOGAR                 FAMI_EDUCACIONPADRE  \
# 0             Cinco      Educación profesional completa
# 1              Tres      Técnica o tecnológica completa
# 2               Dos  Secundaria (Bachillerato) completa
# 3               Dos                 Primaria incompleta
#
#                   FAMI_EDUCACIONMADRE  \
# 0  Secundaria (Bachillerato) completa
# 1      Técnica o tecnológica completa
# 2  Secundaria (Bachillerato) completa
# 3  Secundaria (Bachillerato) completa
#
#                               FAMI_TRABAJOLABORPADRE  \
# 0                                          No aplica
# 1  Trabaja por cuenta propia (por ejemplo plomero...
# 2       Es vendedor o trabaja en atención al público
# 3                                          No aplica
#
#                               FAMI_TRABAJOLABORMADRE FAMI_TIENEINTERNET  \
# 0          Trabaja en el hogar, no trabaja o estudia                 Si
# 1  Es dueño de un negocio pequeño (tiene pocos em...                 Si
# 2       Es vendedor o trabaja en atención al público                 No
# 3  Es dueño de un negocio pequeño (tiene pocos em...                 No
#
#   FAMI_TIENESERVICIOTV FAMI_TIENECOMPUTADOR FAMI_TIENELAVADORA  \
# 0                   Si                   No                 Si
# 1                   Si                   Si                 Si
# 2                   Si                   No                 Si
# 3                   No                   Si                 No
#
#   FAMI_TIENEHORNOMICROOGAS FAMI_TIENEAUTOMOVIL FAMI_TIENEMOTOCICLETA  \
# 0                       Si                  No                    No
# 1                       Si                  Si                    No
# 2                       No                  No                    No
# 3                       No                  No                    No
#
#   FAMI_TIENECONSOLAVIDEOJUEGOS     FAMI_NUMLIBROS  \
# 0                           No  MÁS DE 100 LIBROS
# 1                           No  MÁS DE 100 LIBROS
# 2                           No    26 A 100 LIBROS
# 3                           No     11 A 25 LIBROS
#
#        FAMI_COMELECHEDERIVADOS   FAMI_COMECARNEPESCADOHUEVO  \
# 0       1 o 2 veces por semana       3 a 5 veces por semana
# 1  Todos o casi todos los días       3 a 5 veces por semana
# 2  Todos o casi todos los días  Todos o casi todos los días
# 3  Todos o casi todos los días  Todos o casi todos los días
#
#   FAMI_COMECEREALFRUTOSLEGUMBRE FAMI_SITUACIONECONOMICA  \
# 0  Nunca o rara vez comemos eso                    Peor
# 1        1 o 2 veces por semana                   Mejor
# 2        3 a 5 veces por semana                   Igual
# 3        3 a 5 veces por semana                   Igual
#
#   ESTU_DEDICACIONLECTURADIARIA ESTU_DEDICACIONINTERNET  \
# 0        Entre 30 y 60 minutos   Entre 30 y 60 minutos
# 1        Entre 30 y 60 minutos   Entre 30 y 60 minutos
# 2        Entre 30 y 60 minutos          Más de 3 horas
# 3           30 minutos o menos   Entre 30 y 60 minutos
#
#   ESTU_HORASSEMANATRABAJA ESTU_TIPOREMUNERACION  COLE_CODIGO_ICFES  \
# 0       Menos de 10 horas       Si, en efectivo              39008
# 1       Menos de 10 horas       Si, en efectivo             128611
# 2                       0       Si, en efectivo              35493
# 3         Más de 30 horas       Si, en efectivo             138032
#
#   COLE_COD_DANE_ESTABLECIMIENTO  \
# 0                      1,48E+11
# 1                      3,11E+11
# 2                      1,13E+11
# 3                      1,11E+11
#
#                          COLE_NOMBRE_ESTABLECIMIENTO COLE_GENERO  \
# 0  INSTITUCION EDUCATIVA DEPARTAMENTAL ANTONIO BR...       MIXTO
# 1                                    GIMN SAN ANGELO       MIXTO
# 2  INSTITUCION EDUCATIVA PROMOCION SOCIAL DE C/GENA.       MIXTO
# 3         COLEGIO VIRGINIA GUTIERREZ DE PINEDA (IED)       MIXTO
#
#   COLE_NATURALEZA COLE_CALENDARIO COLE_BILINGUE      COLE_CARACTER  \
# 0         OFICIAL               A             N  TÉCNICO/ACADÉMICO
# 1      NO OFICIAL               A             -          ACADÉMICO
# 2         OFICIAL               A             N  TÉCNICO/ACADÉMICO
# 3         OFICIAL               A             -          ACADÉMICO
#
#   COLE_COD_DANE_SEDE                                   COLE_NOMBRE_SEDE  \
# 0           1,48E+11                   COL DPTAL ANTONIO BRUGES CARMONA
# 1           3,11E+11                                    GIMN SAN ANGELO
# 2           1,13E+11  INSTITUCION EDUCATIVA PROMOCION SOCIAL DE C/GENA.
# 3           1,11E+11   COL VIRGINIA GUTIERREZ DE PINEDA (INS EDUC DIST)
#
#   COLE_SEDE_PRINCIPAL COLE_AREA_UBICACION COLE_JORNADA  \
# 0                   S              URBANO       MAÑANA
# 1                   S              URBANO     COMPLETA
# 2                   S              URBANO       MAÑANA
# 3                   S              URBANO       MAÑANA
#
#    COLE_COD_MCPIO_UBICACION COLE_MCPIO_UBICACION  COLE_COD_DEPTO_UBICACION  \
# 0                     47707            SANTA ANA                        47
# 1                     11001          BOGOTÁ D.C.                        11
# 2                     13001  CARTAGENA DE INDIAS                        13
# 3                     11001          BOGOTÁ D.C.                        11
#
#   COLE_DEPTO_UBICACION ESTU_PRIVADO_LIBERTAD  ESTU_COD_MCPIO_PRESENTACION  \
# 0            MAGDALENA                     N                        47707
# 1               BOGOTÁ                     N                        11001
# 2              BOLIVAR                     N                        13001
# 3               BOGOTÁ                     N                        11001
#
#   ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 0               SANTA ANA               MAGDALENA
# 1             BOGOTÁ D.C.                  BOGOTÁ
# 2     CARTAGENA DE INDIAS                 BOLIVAR
# 3             BOGOTÁ D.C.                  BOGOTÁ
#
#    ESTU_COD_DEPTO_PRESENTACION  PUNT_LECTURA_CRITICA  \
# 0                           47                    47
# 1                           11                    60
# 2                           13                    66
# 3                           11                    62
#
#    PERCENTIL_LECTURA_CRITICA  DESEMP_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# 0                         33                       2                48
# 1                         76                       3                65
# 2                         91                       4                57
# 3                         81                       3                54
#
#    PERCENTIL_MATEMATICAS  DESEMP_MATEMATICAS  PUNT_C_NATURALES  \
# 0                     42                   2                37
# 1                     88                   3                54
# 2                     70                   3                41
# 3                     60                   3                61
#
#    PERCENTIL_C_NATURALES  DESEMP_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  \
# 0                     15                   1                        30
# 1                     71                   2                        59
# 2                     29                   2                        74
# 3                     87                   3                        73
#
#    PERCENTIL_SOCIALES_CIUDADANAS  DESEMP_SOCIALES_CIUDADANAS  PUNT_INGLES  \
# 0                              8                           1        54.00
# 1                             83                           3        63.00
# 2                             99                           4        64.00
# 3                             99                           4        53.00
#
#    PERCENTIL_INGLES DESEMP_INGLES  PUNT_GLOBAL PERCENTIL_GLOBAL  \
# 0                67            A1          208               25
# 1                88            A2          299               83
# 2                89            A2          299               84
# 3                67            A1          309               88
#
#   ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL  ESTU_NSE_ESTABLECIMIENTO  \
# 0  509.421.557.404.314                   2                      2.00
# 1   59.767.864.431.576                   3                      4.00
# 2  507.642.383.644.749                   2                      3.00
# 3  457.791.353.123.516                   2                      3.00
#
#   ESTU_ESTADOINVESTIGACION         ESTU_GENERACION-E
# 0                 PUBLICAR                        NO
# 1                 PUBLICAR                        NO
# 2                 PUBLICAR  GENERACION E - GRATUIDAD
# 3                 PUBLICAR  GENERACION E - GRATUIDAD

# %%
import pandas as pd

# Guardar en parquet sin el índice
icfes.to_parquet("data/raw/icfes.parquet", index=False)

# Leer de nuevo el parquet
df_check = pd.read_parquet("data/raw/icfes.parquet")
print(df_check.head(4))
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M           18/02/2002
# 1                 TI          COLOMBIA           M           28/06/2003
# 2                 TI          COLOMBIA           M            2/06/2001
# 3                 TI          COLOMBIA           M           26/04/2002
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# 2    20194  SB11201940255017      ESTUDIANTE              No         COLOMBIA
# 3    20194  SB11201940154799      ESTUDIANTE              Si         COLOMBIA
#
#   ESTU_ETNIA ESTU_DEPTO_RESIDE ESTU_COD_RESIDE_DEPTO    ESTU_MCPIO_RESIDE  \
# 0          -         MAGDALENA                    47            SANTA ANA
# 1          -            BOGOTÁ                    11          BOGOTÁ D.C.
# 2          -           BOLIVAR                    13  CARTAGENA DE INDIAS
# 3    Ninguno            BOGOTÁ                    11          BOGOTÁ D.C.
#
#   ESTU_COD_RESIDE_MCPIO FAMI_ESTRATOVIVIENDA FAMI_PERSONASHOGAR  \
# 0                 47707            Estrato 3              5 a 6
# 1                 11001            Estrato 3            9 o más
# 2                 13001            Estrato 1              5 a 6
# 3                 11001            Estrato 3              3 a 4
#
#   FAMI_CUARTOSHOGAR                 FAMI_EDUCACIONPADRE  \
# 0             Cinco      Educación profesional completa
# 1              Tres      Técnica o tecnológica completa
# 2               Dos  Secundaria (Bachillerato) completa
# 3               Dos                 Primaria incompleta
#
#                   FAMI_EDUCACIONMADRE  \
# 0  Secundaria (Bachillerato) completa
# 1      Técnica o tecnológica completa
# 2  Secundaria (Bachillerato) completa
# 3  Secundaria (Bachillerato) completa
#
#                               FAMI_TRABAJOLABORPADRE  \
# 0                                          No aplica
# 1  Trabaja por cuenta propia (por ejemplo plomero...
# 2       Es vendedor o trabaja en atención al público
# 3                                          No aplica
#
#                               FAMI_TRABAJOLABORMADRE FAMI_TIENEINTERNET  \
# 0          Trabaja en el hogar, no trabaja o estudia                 Si
# 1  Es dueño de un negocio pequeño (tiene pocos em...                 Si
# 2       Es vendedor o trabaja en atención al público                 No
# 3  Es dueño de un negocio pequeño (tiene pocos em...                 No
#
#   FAMI_TIENESERVICIOTV FAMI_TIENECOMPUTADOR FAMI_TIENELAVADORA  \
# 0                   Si                   No                 Si
# 1                   Si                   Si                 Si
# 2                   Si                   No                 Si
# 3                   No                   Si                 No
#
#   FAMI_TIENEHORNOMICROOGAS FAMI_TIENEAUTOMOVIL FAMI_TIENEMOTOCICLETA  \
# 0                       Si                  No                    No
# 1                       Si                  Si                    No
# 2                       No                  No                    No
# 3                       No                  No                    No
#
#   FAMI_TIENECONSOLAVIDEOJUEGOS     FAMI_NUMLIBROS  \
# 0                           No  MÁS DE 100 LIBROS
# 1                           No  MÁS DE 100 LIBROS
# 2                           No    26 A 100 LIBROS
# 3                           No     11 A 25 LIBROS
#
#        FAMI_COMELECHEDERIVADOS   FAMI_COMECARNEPESCADOHUEVO  \
# 0       1 o 2 veces por semana       3 a 5 veces por semana
# 1  Todos o casi todos los días       3 a 5 veces por semana
# 2  Todos o casi todos los días  Todos o casi todos los días
# 3  Todos o casi todos los días  Todos o casi todos los días
#
#   FAMI_COMECEREALFRUTOSLEGUMBRE FAMI_SITUACIONECONOMICA  \
# 0  Nunca o rara vez comemos eso                    Peor
# 1        1 o 2 veces por semana                   Mejor
# 2        3 a 5 veces por semana                   Igual
# 3        3 a 5 veces por semana                   Igual
#
#   ESTU_DEDICACIONLECTURADIARIA ESTU_DEDICACIONINTERNET  \
# 0        Entre 30 y 60 minutos   Entre 30 y 60 minutos
# 1        Entre 30 y 60 minutos   Entre 30 y 60 minutos
# 2        Entre 30 y 60 minutos          Más de 3 horas
# 3           30 minutos o menos   Entre 30 y 60 minutos
#
#   ESTU_HORASSEMANATRABAJA ESTU_TIPOREMUNERACION  COLE_CODIGO_ICFES  \
# 0       Menos de 10 horas       Si, en efectivo              39008
# 1       Menos de 10 horas       Si, en efectivo             128611
# 2                       0       Si, en efectivo              35493
# 3         Más de 30 horas       Si, en efectivo             138032
#
#   COLE_COD_DANE_ESTABLECIMIENTO  \
# 0                      1,48E+11
# 1                      3,11E+11
# 2                      1,13E+11
# 3                      1,11E+11
#
#                          COLE_NOMBRE_ESTABLECIMIENTO COLE_GENERO  \
# 0  INSTITUCION EDUCATIVA DEPARTAMENTAL ANTONIO BR...       MIXTO
# 1                                    GIMN SAN ANGELO       MIXTO
# 2  INSTITUCION EDUCATIVA PROMOCION SOCIAL DE C/GENA.       MIXTO
# 3         COLEGIO VIRGINIA GUTIERREZ DE PINEDA (IED)       MIXTO
#
#   COLE_NATURALEZA COLE_CALENDARIO COLE_BILINGUE      COLE_CARACTER  \
# 0         OFICIAL               A             N  TÉCNICO/ACADÉMICO
# 1      NO OFICIAL               A             -          ACADÉMICO
# 2         OFICIAL               A             N  TÉCNICO/ACADÉMICO
# 3         OFICIAL               A             -          ACADÉMICO
#
#   COLE_COD_DANE_SEDE                                   COLE_NOMBRE_SEDE  \
# 0           1,48E+11                   COL DPTAL ANTONIO BRUGES CARMONA
# 1           3,11E+11                                    GIMN SAN ANGELO
# 2           1,13E+11  INSTITUCION EDUCATIVA PROMOCION SOCIAL DE C/GENA.
# 3           1,11E+11   COL VIRGINIA GUTIERREZ DE PINEDA (INS EDUC DIST)
#
#   COLE_SEDE_PRINCIPAL COLE_AREA_UBICACION COLE_JORNADA  \
# 0                   S              URBANO       MAÑANA
# 1                   S              URBANO     COMPLETA
# 2                   S              URBANO       MAÑANA
# 3                   S              URBANO       MAÑANA
#
#    COLE_COD_MCPIO_UBICACION COLE_MCPIO_UBICACION  COLE_COD_DEPTO_UBICACION  \
# 0                     47707            SANTA ANA                        47
# 1                     11001          BOGOTÁ D.C.                        11
# 2                     13001  CARTAGENA DE INDIAS                        13
# 3                     11001          BOGOTÁ D.C.                        11
#
#   COLE_DEPTO_UBICACION ESTU_PRIVADO_LIBERTAD  ESTU_COD_MCPIO_PRESENTACION  \
# 0            MAGDALENA                     N                        47707
# 1               BOGOTÁ                     N                        11001
# 2              BOLIVAR                     N                        13001
# 3               BOGOTÁ                     N                        11001
#
#   ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION  \
# 0               SANTA ANA               MAGDALENA
# 1             BOGOTÁ D.C.                  BOGOTÁ
# 2     CARTAGENA DE INDIAS                 BOLIVAR
# 3             BOGOTÁ D.C.                  BOGOTÁ
#
#    ESTU_COD_DEPTO_PRESENTACION  PUNT_LECTURA_CRITICA  \
# 0                           47                    47
# 1                           11                    60
# 2                           13                    66
# 3                           11                    62
#
#    PERCENTIL_LECTURA_CRITICA  DESEMP_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# 0                         33                       2                48
# 1                         76                       3                65
# 2                         91                       4                57
# 3                         81                       3                54
#
#    PERCENTIL_MATEMATICAS  DESEMP_MATEMATICAS  PUNT_C_NATURALES  \
# 0                     42                   2                37
# 1                     88                   3                54
# 2                     70                   3                41
# 3                     60                   3                61
#
#    PERCENTIL_C_NATURALES  DESEMP_C_NATURALES  PUNT_SOCIALES_CIUDADANAS  \
# 0                     15                   1                        30
# 1                     71                   2                        59
# 2                     29                   2                        74
# 3                     87                   3                        73
#
#    PERCENTIL_SOCIALES_CIUDADANAS  DESEMP_SOCIALES_CIUDADANAS  PUNT_INGLES  \
# 0                              8                           1        54.00
# 1                             83                           3        63.00
# 2                             99                           4        64.00
# 3                             99                           4        53.00
#
#    PERCENTIL_INGLES DESEMP_INGLES  PUNT_GLOBAL PERCENTIL_GLOBAL  \
# 0                67            A1          208               25
# 1                88            A2          299               83
# 2                89            A2          299               84
# 3                67            A1          309               88
#
#   ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL  ESTU_NSE_ESTABLECIMIENTO  \
# 0  509.421.557.404.314                   2                      2.00
# 1   59.767.864.431.576                   3                      4.00
# 2  507.642.383.644.749                   2                      3.00
# 3  457.791.353.123.516                   2                      3.00
#
#   ESTU_ESTADOINVESTIGACION         ESTU_GENERACION-E
# 0                 PUBLICAR                        NO
# 1                 PUBLICAR                        NO
# 2                 PUBLICAR  GENERACION E - GRATUIDAD
# 3                 PUBLICAR  GENERACION E - GRATUIDAD

# %% [markdown]
# ##

# %% [markdown]
# # 1.1 COMPRENSIÓN DE LOS DATOS

# %% [markdown]
# ###
# 1. Análisis de dimensiones: Random Forest funciona bien con muchas variables
# 2. Inspección de tipos de datos (numéricos, categóricos, texto, temporales)
# 3. Identificación de valores faltantes (RF puede manejarlos internamente)
# 4. Verificación de cardinalidad de variables categóricas
# 5. Verificación de consistencia en formatos de datos

# %% [markdown]
# ## INFORMACIÓN TABULAR

# %% [markdown]
# ### 1. ANÁLISIS DE DIMENSIONES

# %%
print(f'El dataframe se compone por {icfes.shape[0]} filas y {icfes.shape[1]} columnas')
# Out:
# El dataframe se compone por 546212 filas y 82 columnas

# %% [markdown]
# ### 2. INSPECCIÓN DE TIPOS DE DATOS

# %%
# Numéricas
print("📊 Variables numéricas:")
print(icfes.select_dtypes(include=["int64", "float64"]).columns.tolist())

# Categóricas
print("\n🔤 Variables categóricas:")
print(icfes.select_dtypes(include=["object"]).columns.tolist())

# Booleanas
print("\n✅ Variables booleanas:")
print(icfes.select_dtypes(include=["bool"]).columns.tolist())

# Fechas
print("\n📅 Variables de tipo fecha:")
print(icfes.select_dtypes(include=["datetime"]).columns.tolist())
# Out:
# 📊 Variables numéricas:
# ['PERIODO', 'COLE_CODIGO_ICFES', 'COLE_COD_MCPIO_UBICACION', 'COLE_COD_DEPTO_UBICACION', 'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_COD_DEPTO_PRESENTACION', 'PUNT_LECTURA_CRITICA', 'PERCENTIL_LECTURA_CRITICA', 'DESEMP_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PERCENTIL_MATEMATICAS', 'DESEMP_MATEMATICAS', 'PUNT_C_NATURALES', 'PERCENTIL_C_NATURALES', 'DESEMP_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PERCENTIL_SOCIALES_CIUDADANAS', 'DESEMP_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PERCENTIL_INGLES', 'PUNT_GLOBAL', 'ESTU_NSE_ESTABLECIMIENTO']
#
# 🔤 Variables categóricas:
# ['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO', 'ESTU_FECHANACIMIENTO', 'ESTU_CONSECUTIVO', 'ESTU_ESTUDIANTE', 'ESTU_TIENEETNIA', 'ESTU_PAIS_RESIDE', 'ESTU_ETNIA', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_MCPIO_RESIDE', 'ESTU_COD_RESIDE_MCPIO', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE', 'FAMI_TRABAJOLABORPADRE', 'FAMI_TRABAJOLABORMADRE', 'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENELAVADORA', 'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENEMOTOCICLETA', 'FAMI_TIENECONSOLAVIDEOJUEGOS', 'FAMI_NUMLIBROS', 'FAMI_COMELECHEDERIVADOS', 'FAMI_COMECARNEPESCADOHUEVO', 'FAMI_COMECEREALFRUTOSLEGUMBRE', 'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA', 'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA', 'ESTU_TIPOREMUNERACION', 'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_GENERO', 'COLE_NATURALEZA', 'COLE_CALENDARIO', 'COLE_BILINGUE', 'COLE_CARACTER', 'COLE_COD_DANE_SEDE', 'COLE_NOMBRE_SEDE', 'COLE_SEDE_PRINCIPAL', 'COLE_AREA_UBICACION', 'COLE_JORNADA', 'COLE_MCPIO_UBICACION', 'COLE_DEPTO_UBICACION', 'ESTU_PRIVADO_LIBERTAD', 'ESTU_MCPIO_PRESENTACION', 'ESTU_DEPTO_PRESENTACION', 'DESEMP_INGLES', 'PERCENTIL_GLOBAL', 'ESTU_INSE_INDIVIDUAL', 'ESTU_NSE_INDIVIDUAL', 'ESTU_ESTADOINVESTIGACION', 'ESTU_GENERACION-E']
#
# ✅ Variables booleanas:
# []
#
# 📅 Variables de tipo fecha:
# []

# %%
# Numéricas
numeric_cols = icfes.select_dtypes(include=["int64", "float64"]).columns.tolist()
print("📊 Variables numéricas:", len(numeric_cols))

# Categóricas
categorical_cols = icfes.select_dtypes(include=["object"]).columns.tolist()
print("🔤 Variables categóricas:", len(categorical_cols))

# Booleanas
bool_cols = icfes.select_dtypes(include=["bool"]).columns.tolist()
print("✅ Variables booleanas:", len(bool_cols))

# Fechas
date_cols = icfes.select_dtypes(include=["datetime"]).columns.tolist()
print("📅 Variables de tipo fecha:", len(date_cols))
# Out:
# 📊 Variables numéricas: 22
# 🔤 Variables categóricas: 60
# ✅ Variables booleanas: 0
# 📅 Variables de tipo fecha: 0

# %%
icfes.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
#        'ESTU_ESTUDIANTE', 'ESTU_TIENEETNIA', 'ESTU_PAIS_RESIDE', 'ESTU_ETNIA',
#        'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_MCPIO_RESIDE',
#        'ESTU_COD_RESIDE_MCPIO', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE',
#        'FAMI_TRABAJOLABORPADRE', 'FAMI_TRABAJOLABORMADRE',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENEMOTOCICLETA', 'FAMI_TIENECONSOLAVIDEOJUEGOS',
#        'FAMI_NUMLIBROS', 'FAMI_COMELECHEDERIVADOS',
#        'FAMI_COMECARNEPESCADOHUEVO', 'FAMI_COMECEREALFRUTOSLEGUMBRE',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA',
#        'ESTU_TIPOREMUNERACION', 'COLE_CODIGO_ICFES',
#        'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_NOMBRE_ESTABLECIMIENTO',
#        'COLE_GENERO', 'COLE_NATURALEZA', 'COLE_CALENDARIO', 'COLE_BILINGUE',
#        'COLE_CARACTER', 'COLE_COD_DANE_SEDE', 'COLE_NOMBRE_SEDE',
#        'COLE_SEDE_PRINCIPAL', 'COLE_AREA_UBICACION', 'COLE_JORNADA',
#        'COLE_COD_MCPIO_UBICACION', 'COLE_MCPIO_UBICACION',
#        'COLE_COD_DEPTO_UBICACION', 'COLE_DEPTO_UBICACION',
#        'ESTU_PRIVADO_LIBERTAD', 'ESTU_COD_MCPIO_PRESENTACION',
#        'ESTU_MCPIO_PRESENTACION', 'ESTU_DEPTO_PRESENTACION',
#        'ESTU_COD_DEPTO_PRESENTACION', 'PUNT_LECTURA_CRITICA',
#        'PERCENTIL_LECTURA_CRITICA', 'DESEMP_LECTURA_CRITICA',
#        'PUNT_MATEMATICAS', 'PERCENTIL_MATEMATICAS', 'DESEMP_MATEMATICAS',
#        'PUNT_C_NATURALES', 'PERCENTIL_C_NATURALES', 'DESEMP_C_NATURALES',
#        'PUNT_SOCIALES_CIUDADANAS', 'PERCENTIL_SOCIALES_CIUDADANAS',
#        'DESEMP_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PERCENTIL_INGLES',
#        'DESEMP_INGLES', 'PUNT_GLOBAL', 'PERCENTIL_GLOBAL',
#        'ESTU_INSE_INDIVIDUAL', 'ESTU_NSE_INDIVIDUAL',
#        'ESTU_NSE_ESTABLECIMIENTO', 'ESTU_ESTADOINVESTIGACION',
#        'ESTU_GENERACION-E'],
#       dtype='object')

# %% [markdown]
# ### 3. IDENTIFICAR VALORES FALTANTES

# %%
import pandas as pd

# Filtrar solo las columnas con NA
na_counts = icfes.isna().sum()
na_counts = na_counts[na_counts > 0]  # Solo variables con NAs

# Calcular el porcentaje de NAs sobre el total de observaciones
na_percentage = (na_counts / len(icfes)) * 100

# Crear DataFrame con los resultados
na_summary = pd.DataFrame({'Variable': na_counts.index, 'Conteo_NA': na_counts.values, 'Porcentaje_NA': na_percentage.values})

# Ordenar por porcentaje de NA
na_summary = na_summary.sort_values(by="Porcentaje_NA", ascending=False)

# Mostrar la tabla
print(na_summary)
# Out:
#                          Variable  Conteo_NA  Porcentaje_NA
# 23        ESTU_DEDICACIONINTERNET      30298           5.55
# 20  FAMI_COMECEREALFRUTOSLEGUMBRE      22332           4.09
# 18        FAMI_COMELECHEDERIVADOS      22305           4.08
# 10           FAMI_TIENESERVICIOTV      22280           4.08
# 6             FAMI_EDUCACIONMADRE      20959           3.84
# 29            ESTU_NSE_INDIVIDUAL      17041           3.12
# 25          ESTU_TIPOREMUNERACION      15508           2.84
# 26                  COLE_CARACTER      13748           2.52
# 19     FAMI_COMECARNEPESCADOHUEVO       9625           1.76
# 15          FAMI_TIENEMOTOCICLETA       8817           1.61
# 17                 FAMI_NUMLIBROS       8654           1.58
# 13       FAMI_TIENEHORNOMICROOGAS       8630           1.58
# 3              FAMI_PERSONASHOGAR       8463           1.55
# 9              FAMI_TIENEINTERNET       8337           1.53
# 5             FAMI_EDUCACIONPADRE       8292           1.52
# 21        FAMI_SITUACIONECONOMICA       8259           1.51
# 14            FAMI_TIENEAUTOMOVIL       8206           1.50
# 11           FAMI_TIENECOMPUTADOR       8185           1.50
# 7          FAMI_TRABAJOLABORPADRE       8131           1.49
# 16   FAMI_TIENECONSOLAVIDEOJUEGOS       7725           1.41
# 12             FAMI_TIENELAVADORA       7643           1.40
# 8          FAMI_TRABAJOLABORMADRE       7469           1.37
# 4               FAMI_CUARTOSHOGAR       6418           1.18
# 22   ESTU_DEDICACIONLECTURADIARIA        627           0.11
# 24        ESTU_HORASSEMANATRABAJA        381           0.07
# 0               ESTU_DEPTO_RESIDE        377           0.07
# 1               ESTU_MCPIO_RESIDE        377           0.07
# 30       ESTU_NSE_ESTABLECIMIENTO         44           0.01
# 2            FAMI_ESTRATOVIVIENDA         26           0.00
# 27                    PUNT_INGLES         19           0.00
# 28           ESTU_INSE_INDIVIDUAL          4           0.00

# %%
plt.figure(figsize=(18, 16))
sns.heatmap(icfes.isnull(),cmap = 'magma',cbar = False)
# Out:
# <Axes: >

# %%
import missingno as msno

# Mapa de calor de correlación de NAs
msno.heatmap(icfes)

# Gráfico de barras por variable
msno.bar(icfes)

# Dendrograma para ver patrones de NA compartidos
msno.dendrogram(icfes)
# Out:
# <Axes: >

# %%
# Conteo de NA por fila
row_na = icfes.isna().sum(axis=1)

# Filas con más del 50% de NA
incompletas = icfes[row_na > (icfes.shape[1] / 2)]
print(incompletas.shape)
# Out:
# (0, 82)

# %%
import pandas as pd

# Matriz de correlación de NAs
na_corr = icfes.isna().corr()

# Umbral de correlación (ajústalo si quieres ser más estricto o más laxo)
threshold = 0.8

# Para guardar los grupos
clusters = []
visited = set()

for col in na_corr.columns:
    if col not in visited:
        # Encuentra todas las variables correlacionadas con 'col' >= threshold
        correlated = na_corr.index[na_corr[col] >= threshold].tolist()
        
        # Si hay más de una variable, consideramos que forman grupo
        if len(correlated) > 1:
            clusters.append(correlated)
            visited.update(correlated)

# Mostrar resultados
for i, cluster in enumerate(clusters, 1):
    print(f"🔹 Grupo {i}: {cluster}")
# Out:
# 🔹 Grupo 1: ['ESTU_DEPTO_RESIDE', 'ESTU_MCPIO_RESIDE']
# 🔹 Grupo 2: ['FAMI_PERSONASHOGAR', 'FAMI_EDUCACIONPADRE', 'FAMI_TRABAJOLABORPADRE', 'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEMOTOCICLETA', 'FAMI_NUMLIBROS', 'FAMI_COMECARNEPESCADOHUEVO', 'FAMI_SITUACIONECONOMICA']
# 🔹 Grupo 3: ['FAMI_CUARTOSHOGAR', 'FAMI_TRABAJOLABORMADRE', 'FAMI_TIENELAVADORA', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENECONSOLAVIDEOJUEGOS']
# 🔹 Grupo 4: ['FAMI_EDUCACIONMADRE', 'FAMI_TIENESERVICIOTV', 'FAMI_COMELECHEDERIVADOS', 'FAMI_COMECEREALFRUTOSLEGUMBRE']
# 🔹 Grupo 5: ['FAMI_COMELECHEDERIVADOS', 'FAMI_COMECEREALFRUTOSLEGUMBRE', 'ESTU_DEDICACIONINTERNET']
# 🔹 Grupo 6: ['ESTU_TIPOREMUNERACION', 'ESTU_NSE_INDIVIDUAL']

# %%
num_vars = icfes.select_dtypes(include=["int64", "float64"])
print("Variables numéricas:", num_vars.columns.tolist())
# Out:
# Variables numéricas: ['PERIODO', 'COLE_CODIGO_ICFES', 'COLE_COD_MCPIO_UBICACION', 'COLE_COD_DEPTO_UBICACION', 'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_COD_DEPTO_PRESENTACION', 'PUNT_LECTURA_CRITICA', 'PERCENTIL_LECTURA_CRITICA', 'DESEMP_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PERCENTIL_MATEMATICAS', 'DESEMP_MATEMATICAS', 'PUNT_C_NATURALES', 'PERCENTIL_C_NATURALES', 'DESEMP_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 'PERCENTIL_SOCIALES_CIUDADANAS', 'DESEMP_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PERCENTIL_INGLES', 'PUNT_GLOBAL', 'ESTU_NSE_ESTABLECIMIENTO']

# %% [markdown]
# ### 4. CARDINALIDAD DE VARIABLES CATEGÓRICAS

# %%
# Filtrar variables categóricas
cat_vars = icfes.select_dtypes(include=['object'])

# Número de categorías únicas por variable
cardinalidad = cat_vars.nunique().sort_values(ascending=False)
print(cardinalidad)
# Out:
# ESTU_CONSECUTIVO                 546212
# ESTU_INSE_INDIVIDUAL             469865
# ESTU_FECHANACIMIENTO              11663
# COLE_NOMBRE_SEDE                  10284
# COLE_NOMBRE_ESTABLECIMIENTO        9372
# ESTU_COD_RESIDE_MCPIO              1115
# ESTU_MCPIO_RESIDE                  1031
# COLE_MCPIO_UBICACION               1030
# ESTU_MCPIO_PRESENTACION             472
# COLE_COD_DANE_SEDE                  234
# COLE_COD_DANE_ESTABLECIMIENTO       232
# PERCENTIL_GLOBAL                    101
# ESTU_COD_RESIDE_DEPTO                35
# ESTU_DEPTO_RESIDE                    34
# ESTU_NACIONALIDAD                    33
# ESTU_PAIS_RESIDE                     33
# ESTU_DEPTO_PRESENTACION              33
# COLE_DEPTO_UBICACION                 33
# ESTU_ETNIA                           21
# FAMI_TRABAJOLABORMADRE               14
# FAMI_TRABAJOLABORPADRE               14
# FAMI_EDUCACIONMADRE                  13
# FAMI_EDUCACIONPADRE                  13
# ESTU_TIPODOCUMENTO                   10
# FAMI_ESTRATOVIVIENDA                  8
# FAMI_CUARTOSHOGAR                     7
# FAMI_PERSONASHOGAR                    6
# ESTU_DEDICACIONINTERNET               6
# ESTU_DEDICACIONLECTURADIARIA          6
# COLE_JORNADA                          6
# ESTU_HORASSEMANATRABAJA               6
# ESTU_NSE_INDIVIDUAL                   5
# FAMI_NUMLIBROS                        5
# DESEMP_INGLES                         5
# FAMI_COMECEREALFRUTOSLEGUMBRE         5
# FAMI_COMECARNEPESCADOHUEVO            5
# FAMI_COMELECHEDERIVADOS               5
# COLE_CARACTER                         5
# ESTU_TIPOREMUNERACION                 5
# FAMI_SITUACIONECONOMICA               4
# ESTU_GENERACION-E                     4
# ESTU_TIENEETNIA                       3
# FAMI_TIENEINTERNET                    3
# ESTU_GENERO                           3
# ESTU_ESTADOINVESTIGACION              3
# FAMI_TIENECONSOLAVIDEOJUEGOS          3
# FAMI_TIENEAUTOMOVIL                   3
# FAMI_TIENEMOTOCICLETA                 3
# FAMI_TIENELAVADORA                    3
# FAMI_TIENECOMPUTADOR                  3
# FAMI_TIENESERVICIOTV                  3
# FAMI_TIENEHORNOMICROOGAS              3
# COLE_CALENDARIO                       3
# COLE_BILINGUE                         3
# COLE_GENERO                           3
# COLE_NATURALEZA                       2
# COLE_SEDE_PRINCIPAL                   2
# ESTU_PRIVADO_LIBERTAD                 2
# COLE_AREA_UBICACION                   2
# ESTU_ESTUDIANTE                       1
# dtype: int64

# %%
for col in cat_vars.columns:
    print(f"\n📌 {col} ({cat_vars[col].nunique()} categorías)")
    print(cat_vars[col].value_counts().head(5))  # top 5 categorías
# Out:
# 📌 ESTU_TIPODOCUMENTO (10 categorías)
# ESTU_TIPODOCUMENTO
# TI     445780
# CC      91921
# CR       6123
# CE       1225
# NES       822
# Name: count, dtype: int64
#
# 📌 ESTU_NACIONALIDAD (33 categorías)
# ESTU_NACIONALIDAD
# COLOMBIA          544918
# VENEZUELA           1109
# ESTADOS UNIDOS        52
# ESPAÑA                33
# ECUADOR               26
# Name: count, dtype: int64
#
# 📌 ESTU_GENERO (3 categorías)
# ESTU_GENERO
# F    295994
# M    250097
# -       121
# Name: count, dtype: int64
#
# 📌 ESTU_FECHANACIMIENTO (11663 categorías)
# ESTU_FECHANACIMIENTO
# 1/01/1900     1826
# 20/09/2002     866
# 17/09/2002     859
# 13/09/2002     851
# 24/09/2002     850
# Name: count, dtype: int64
#
# 📌 ESTU_CONSECUTIVO (546212 categorías)
# ESTU_CONSECUTIVO
# SB11201940074679    1
# SB11201940031558    1
# SB11201940303339    1
# SB11201940255017    1
# SB11201940271799    1
# Name: count, dtype: int64
#
# 📌 ESTU_ESTUDIANTE (1 categorías)
# ESTU_ESTUDIANTE
# ESTUDIANTE    546212
# Name: count, dtype: int64
#
# 📌 ESTU_TIENEETNIA (3 categorías)
# ESTU_TIENEETNIA
# No    506074
# Si     39761
# -        377
# Name: count, dtype: int64
#
# 📌 ESTU_PAIS_RESIDE (33 categorías)
# ESTU_PAIS_RESIDE
# COLOMBIA          544918
# VENEZUELA           1109
# ESTADOS UNIDOS        52
# ESPAÑA                33
# ECUADOR               26
# Name: count, dtype: int64
#
# 📌 ESTU_ETNIA (21 categorías)
# ESTU_ETNIA
# -                                506203
# Comunidad afrodescendiente        19534
# Ninguno                            4442
# Zenú                               3281
# Otro grupo étnico minoritario      3150
# Name: count, dtype: int64
#
# 📌 ESTU_DEPTO_RESIDE (34 categorías)
# ESTU_DEPTO_RESIDE
# BOGOTÁ          83600
# ANTIOQUIA       74228
# VALLE           38640
# CUNDINAMARCA    36196
# ATLANTICO       32179
# Name: count, dtype: int64
#
# 📌 ESTU_COD_RESIDE_DEPTO (35 categorías)
# ESTU_COD_RESIDE_DEPTO
# 11    83600
# 5     74228
# 76    38640
# 25    36196
# 8     32179
# Name: count, dtype: int64
#
# 📌 ESTU_MCPIO_RESIDE (1031 categorías)
# ESTU_MCPIO_RESIDE
# BOGOTÁ D.C.            83600
# MEDELLÍN               28222
# BARRANQUILLA           17177
# CALI                   16542
# CARTAGENA DE INDIAS    13535
# Name: count, dtype: int64
#
# 📌 ESTU_COD_RESIDE_MCPIO (1115 categorías)
# ESTU_COD_RESIDE_MCPIO
# 11001    83600
# 5001     28222
# 8001     17177
# 76001    16542
# 13001    13535
# Name: count, dtype: int64
#
# 📌 FAMI_ESTRATOVIVIENDA (8 categorías)
# FAMI_ESTRATOVIVIENDA
# Estrato 2    188314
# Estrato 1    159977
# Estrato 3    108692
# -             34481
# Estrato 4     25810
# Name: count, dtype: int64
#
# 📌 FAMI_PERSONASHOGAR (6 categorías)
# FAMI_PERSONASHOGAR
# 3 a 4      257604
# 5 a 6      170028
# 7 a 8       44984
# 1 a 2       39843
# 9 o más     17760
# Name: count, dtype: int64
#
# 📌 FAMI_CUARTOSHOGAR (7 categorías)
# FAMI_CUARTOSHOGAR
# Tres      207232
# Dos       189042
# Cuatro     70635
# Uno        28276
# Cinco      21966
# Name: count, dtype: int64
#
# 📌 FAMI_EDUCACIONPADRE (13 categorías)
# FAMI_EDUCACIONPADRE
# Secundaria (Bachillerato) completa      117488
# Primaria incompleta                     101387
# Secundaria (Bachillerato) incompleta     71295
# Primaria completa                        54141
# Educación profesional completa           46404
# Name: count, dtype: int64
#
# 📌 FAMI_EDUCACIONMADRE (13 categorías)
# FAMI_EDUCACIONMADRE
# Secundaria (Bachillerato) completa      136286
# Primaria incompleta                      80062
# Secundaria (Bachillerato) incompleta     76353
# Educación profesional completa           54474
# Primaria completa                        53441
# Name: count, dtype: int64
#
# 📌 FAMI_TRABAJOLABORPADRE (14 categorías)
# FAMI_TRABAJOLABORPADRE
# Es agricultor, pesquero o jornalero                              78187
# Trabaja por cuenta propia (por ejemplo plomero, electricista)    60949
# Es operario de máquinas o conduce vehículos (taxita, chofer)     56948
# No aplica                                                        49029
# No sabe                                                          44249
# Name: count, dtype: int64
#
# 📌 FAMI_TRABAJOLABORMADRE (14 categorías)
# FAMI_TRABAJOLABORMADRE
# Trabaja en el hogar, no trabaja o estudia                                                               213377
# Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc     48129
# Trabaja como personal de limpieza, mantenimiento, seguridad o construcción                               46890
# Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)                   44407
# Trabaja como profesional (por ejemplo médico, abogado, ingeniero)                                        41939
# Name: count, dtype: int64
#
# 📌 FAMI_TIENEINTERNET (3 categorías)
# FAMI_TIENEINTERNET
# Si    314042
# No    201199
# -      22634
# Name: count, dtype: int64
#
# 📌 FAMI_TIENESERVICIOTV (3 categorías)
# FAMI_TIENESERVICIOTV
# Si    391419
# No    122866
# -       9647
# Name: count, dtype: int64
#
# 📌 FAMI_TIENECOMPUTADOR (3 categorías)
# FAMI_TIENECOMPUTADOR
# Si    295409
# No    233827
# -       8791
# Name: count, dtype: int64
#
# 📌 FAMI_TIENELAVADORA (3 categorías)
# FAMI_TIENELAVADORA
# Si    405542
# No    123912
# -       9115
# Name: count, dtype: int64
#
# 📌 FAMI_TIENEHORNOMICROOGAS (3 categorías)
# FAMI_TIENEHORNOMICROOGAS
# No    280967
# Si    247694
# -       8921
# Name: count, dtype: int64
#
# 📌 FAMI_TIENEAUTOMOVIL (3 categorías)
# FAMI_TIENEAUTOMOVIL
# No    401388
# Si    126735
# -       9883
# Name: count, dtype: int64
#
# 📌 FAMI_TIENEMOTOCICLETA (3 categorías)
# FAMI_TIENEMOTOCICLETA
# No    308054
# Si    221051
# -       8290
# Name: count, dtype: int64
#
# 📌 FAMI_TIENECONSOLAVIDEOJUEGOS (3 categorías)
# FAMI_TIENECONSOLAVIDEOJUEGOS
# No    410475
# Si    117642
# -      10370
# Name: count, dtype: int64
#
# 📌 FAMI_NUMLIBROS (5 categorías)
# FAMI_NUMLIBROS
# 0 A 10 LIBROS        207526
# 11 A 25 LIBROS       153968
# 26 A 100 LIBROS      105653
# -                     35998
# MÁS DE 100 LIBROS     34413
# Name: count, dtype: int64
#
# 📌 FAMI_COMELECHEDERIVADOS (5 categorías)
# FAMI_COMELECHEDERIVADOS
# 1 o 2 veces por semana          170538
# Todos o casi todos los días     160798
# 3 a 5 veces por semana          133932
# Nunca o rara vez comemos eso     44252
# -                                14387
# Name: count, dtype: int64
#
# 📌 FAMI_COMECARNEPESCADOHUEVO (5 categorías)
# FAMI_COMECARNEPESCADOHUEVO
# Todos o casi todos los días     209228
# 3 a 5 veces por semana          154432
# 1 o 2 veces por semana          124422
# Nunca o rara vez comemos eso     25600
# -                                22905
# Name: count, dtype: int64
#
# 📌 FAMI_COMECEREALFRUTOSLEGUMBRE (5 categorías)
# FAMI_COMECEREALFRUTOSLEGUMBRE
# 1 o 2 veces por semana          198491
# 3 a 5 veces por semana          154261
# Todos o casi todos los días      88346
# Nunca o rara vez comemos eso     71536
# -                                11246
# Name: count, dtype: int64
#
# 📌 FAMI_SITUACIONECONOMICA (4 categorías)
# FAMI_SITUACIONECONOMICA
# Igual    322524
# Mejor    133690
# Peor      72123
# -          9616
# Name: count, dtype: int64
#
# 📌 ESTU_DEDICACIONLECTURADIARIA (6 categorías)
# ESTU_DEDICACIONLECTURADIARIA
# 30 minutos o menos            199094
# Entre 30 y 60 minutos         144272
# No leo por entretenimiento     95621
# Entre 1 y 2 horas              55480
# -                              31108
# Name: count, dtype: int64
#
# 📌 ESTU_DEDICACIONINTERNET (6 categorías)
# ESTU_DEDICACIONINTERNET
# Entre 1 y 3 horas        157557
# Entre 30 y 60 minutos    134383
# Más de 3 horas           100134
# 30 minutos o menos        90517
# No Navega Internet        30697
# Name: count, dtype: int64
#
# 📌 ESTU_HORASSEMANATRABAJA (6 categorías)
# ESTU_HORASSEMANATRABAJA
# 0                      354503
# Menos de 10 horas       97913
# Entre 11 y 20 horas     41729
# Más de 30 horas         19907
# -                       16509
# Name: count, dtype: int64
#
# 📌 ESTU_TIPOREMUNERACION (5 categorías)
# ESTU_TIPOREMUNERACION
# No                           377436
# Si, en efectivo              134786
# Si, en especie                 8530
# Si, en efectivo y especie      7361
# -                              2591
# Name: count, dtype: int64
#
# 📌 COLE_COD_DANE_ESTABLECIMIENTO (232 categorías)
# COLE_COD_DANE_ESTABLECIMIENTO
# 1,11E+11    41625
# 1,05E+11    37044
# 3,11E+11    32278
# 1,76E+11    19118
# 3,05E+11    15481
# Name: count, dtype: int64
#
# 📌 COLE_NOMBRE_ESTABLECIMIENTO (9372 categorías)
# COLE_NOMBRE_ESTABLECIMIENTO
# INSTITUCION EDUCATIVA FRANCISCO JOSE DE CALDAS    1147
# IE JORGE ELIECER GAITAN                            941
# INST EDUC CEFA                                     869
# COL COOP SAN ANTONIO DE PRADO (AC)                 840
# COLEGIO TECNISISTEMAS                              823
# Name: count, dtype: int64
#
# 📌 COLE_GENERO (3 categorías)
# COLE_GENERO
# MIXTO        528780
# FEMENINO      13462
# MASCULINO      3970
# Name: count, dtype: int64
#
# 📌 COLE_NATURALEZA (2 categorías)
# COLE_NATURALEZA
# OFICIAL       416011
# NO OFICIAL    130201
# Name: count, dtype: int64
#
# 📌 COLE_CALENDARIO (3 categorías)
# COLE_CALENDARIO
# A       541901
# OTRO      3171
# B         1140
# Name: count, dtype: int64
#
# 📌 COLE_BILINGUE (3 categorías)
# COLE_BILINGUE
# N    453280
# -     87432
# S      5500
# Name: count, dtype: int64
#
# 📌 COLE_CARACTER (5 categorías)
# COLE_CARACTER
# ACADÉMICO            284200
# TÉCNICO/ACADÉMICO    181238
# TÉCNICO               58972
# NO APLICA              7008
# -                      1046
# Name: count, dtype: int64
#
# 📌 COLE_COD_DANE_SEDE (234 categorías)
# COLE_COD_DANE_SEDE
# 1,11E+11    42137
# 1,05E+11    36744
# 3,11E+11    32278
# 1,76E+11    19081
# 3,05E+11    15446
# Name: count, dtype: int64
#
# 📌 COLE_NOMBRE_SEDE (10284 categorías)
# COLE_NOMBRE_SEDE
# INSTITUTO TECNICO INDUSTRIAL          881
# INST EDUC CEFA                        869
# COL COOP SAN ANTONIO DE PRADO (AC)    840
# JORGE ELIECER GAITAN                  817
# SIMON BOLIVAR                         713
# Name: count, dtype: int64
#
# 📌 COLE_SEDE_PRINCIPAL (2 categorías)
# COLE_SEDE_PRINCIPAL
# S    523322
# N     22890
# Name: count, dtype: int64
#
# 📌 COLE_AREA_UBICACION (2 categorías)
# COLE_AREA_UBICACION
# URBANO    460467
# RURAL      85745
# Name: count, dtype: int64
#
# 📌 COLE_JORNADA (6 categorías)
# COLE_JORNADA
# MAÑANA      257060
# COMPLETA     89520
# UNICA        67361
# TARDE        59049
# SABATINA     39098
# Name: count, dtype: int64
#
# 📌 COLE_MCPIO_UBICACION (1030 categorías)
# COLE_MCPIO_UBICACION
# BOGOTÁ D.C.            82832
# MEDELLÍN               28690
# BARRANQUILLA           17046
# CALI                   16666
# CARTAGENA DE INDIAS    13437
# Name: count, dtype: int64
#
# 📌 COLE_DEPTO_UBICACION (33 categorías)
# COLE_DEPTO_UBICACION
# BOGOTÁ          82832
# ANTIOQUIA       74182
# VALLE           38664
# CUNDINAMARCA    37049
# ATLANTICO       32235
# Name: count, dtype: int64
#
# 📌 ESTU_PRIVADO_LIBERTAD (2 categorías)
# ESTU_PRIVADO_LIBERTAD
# N    546086
# S       126
# Name: count, dtype: int64
#
# 📌 ESTU_MCPIO_PRESENTACION (472 categorías)
# ESTU_MCPIO_PRESENTACION
# BOGOTÁ D.C.            84122
# MEDELLÍN               27151
# BARRANQUILLA           18833
# CALI                   16642
# CARTAGENA DE INDIAS    14674
# Name: count, dtype: int64
#
# 📌 ESTU_DEPTO_PRESENTACION (33 categorías)
# ESTU_DEPTO_PRESENTACION
# BOGOTÁ          84122
# ANTIOQUIA       74355
# VALLE           38898
# CUNDINAMARCA    35152
# ATLANTICO       32834
# Name: count, dtype: int64
#
# 📌 DESEMP_INGLES (5 categorías)
# DESEMP_INGLES
# A-    271183
# A1    153405
# A2     79450
# B1     34853
# B+      7321
# Name: count, dtype: int64
#
# 📌 PERCENTIL_GLOBAL (101 categorías)
# PERCENTIL_GLOBAL
# 22    6443
# 69    6280
# 19    6183
# 3     6178
# 46    6111
# Name: count, dtype: int64
#
# 📌 ESTU_INSE_INDIVIDUAL (469865 categorías)
# ESTU_INSE_INDIVIDUAL
# -                      17041
# 759.320.669.193.899      296
# 848.363.660.916.828      245
# 775.660.409.172.602      219
# 746.270.692.205.014      212
# Name: count, dtype: int64
#
# 📌 ESTU_NSE_INDIVIDUAL (5 categorías)
# ESTU_NSE_INDIVIDUAL
# 2    197566
# 3    193431
# 1     94455
# 4     43715
# -         4
# Name: count, dtype: int64
#
# 📌 ESTU_ESTADOINVESTIGACION (3 categorías)
# ESTU_ESTADOINVESTIGACION
# PUBLICAR                                  545755
# NO SE COMPROBO IDENTIDAD DEL EXAMINADO       272
# VALIDEZ OFICINA JURÍDICA                     185
# Name: count, dtype: int64
#
# 📌 ESTU_GENERACION-E (4 categorías)
# ESTU_GENERACION-E
# GENERACION E - GRATUIDAD                   297357
# NO                                         242966
# GENERACION E - EXCELENCIA NACIONAL           5703
# GENERACION E - EXCELENCIA DEPARTAMENTAL       186
# Name: count, dtype: int64

# %%
import numpy as np

# Extraer variable
y = icfes['PUNT_GLOBAL'].dropna()

# Normalización (Z-score)
mu, sigma = y.mean(), y.std()
z_scores = (y - mu) / sigma

# %%
# Índices de los outliers
outlier_idx = y.index[abs(z_scores) > 3]

# Guardar como lista de tuplas (índice, valor, z-score)
outliers = [(i, y.loc[i], z_scores.loc[i]) for i in outlier_idx]

print("Número de outliers:", len(outliers))
print("Ejemplo:", outliers[:5])
# Out:
# Número de outliers: 588
# Ejemplo: [(316, np.int64(80), np.float64(-3.2340265926888967)), (684, np.int64(90), np.float64(-3.039424306174579)), (3653, np.int64(403), np.float64(3.051627261723554)), (5023, np.int64(416), np.float64(3.3046102341921664)), (6411, np.int64(411), np.float64(3.207309090935008))]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

plt.figure(figsize=(16,10))

# Histograma con KDE
sns.histplot(y, kde=True, stat="density", bins=30, color="lightgreen", edgecolor="black")

# Curva normal teórica
xmin, xmax = plt.xlim()
xx = np.linspace(xmin, xmax, 200)
plt.plot(xx, norm.pdf(xx, mu, sigma), 'r', lw=2, label="Normal ajustada")

# Líneas verticales de 1σ, 2σ, 3σ
for k, col in zip([1,2,3], ["black","orange","red"]):
    plt.axvline(mu + k*sigma, color=col, linestyle="--")
    plt.axvline(mu - k*sigma, color=col, linestyle="--", label=f"{k}σ")

# Graficar puntos outliers
plt.scatter(y.loc[outlier_idx], [0]*len(outlier_idx), 
            color="blue", marker="x", s=60, label="Outliers")

plt.title("Distribución de PUNT_GLOBAL con detección de outliers")
plt.xlabel("Puntaje Global")
plt.ylabel("Densidad")
plt.legend()
plt.show()

# %% [markdown]
# ### 5. CONSISTENCIA DEL FORMATO DE DATOS

# %%
for col in icfes.select_dtypes(include=["int64", "float64"]).columns:
    n_unique = icfes[col].nunique()
    if n_unique < 20:  # arbitrario, pocos valores únicos
        print(f"⚠️ {col} es numérica pero parece categórica ({n_unique} valores únicos)")
# Out:
# ⚠️ PERIODO es numérica pero parece categórica (1 valores únicos)
# ⚠️ DESEMP_LECTURA_CRITICA es numérica pero parece categórica (4 valores únicos)
# ⚠️ DESEMP_MATEMATICAS es numérica pero parece categórica (4 valores únicos)
# ⚠️ DESEMP_C_NATURALES es numérica pero parece categórica (4 valores únicos)
# ⚠️ DESEMP_SOCIALES_CIUDADANAS es numérica pero parece categórica (4 valores únicos)
# ⚠️ ESTU_NSE_ESTABLECIMIENTO es numérica pero parece categórica (4 valores únicos)

# %%
import pandas as pd
import numpy as np
from collections import Counter

# Función para identificar valores problemáticos en columnas que deberían ser numéricas
def identificar_inconsistencias_numericas(df, columnas=None):
    """
    Identifica valores no numéricos en columnas que podrían ser numéricas
    """
    if columnas is None:
        columnas = df.select_dtypes(include=["object"]).columns
    
    resultados = {}
    
    for col in columnas:
        print(f"\n{'='*50}")
        print(f"ANALIZANDO COLUMNA: {col}")
        print(f"{'='*50}")
        
        # Valores únicos
        valores_unicos = df[col].unique()
        print(f"Valores únicos: {len(valores_unicos)}")
        
        # Separar valores que se pueden convertir a numérico de los que no
        valores_numericos = []
        valores_problematicos = []
        
        for valor in valores_unicos:
            if pd.isna(valor):  # NaN
                continue
            try:
                float(str(valor).strip())
                valores_numericos.append(valor)
            except (ValueError, TypeError):
                valores_problematicos.append(valor)
        
        print(f"Valores numéricos: {len(valores_numericos)}")
        print(f"Valores problemáticos: {len(valores_problematicos)}")
        
        if valores_problematicos:
            print(f"\n⚠️  VALORES PROBLEMÁTICOS ENCONTRADOS:")
            conteo_problematicos = df[col].value_counts()
            for valor in valores_problematicos:
                frecuencia = conteo_problematicos.get(valor, 0)
                print(f"  '{valor}' (tipo: {type(valor).__name__}) - Aparece {frecuencia} veces")
        
        if valores_numericos:
            print(f"\n✅ Valores numéricos encontrados:")
            print(f"  Rango: {min(valores_numericos)} - {max(valores_numericos)}")
        
        # Intentar conversión con diferentes estrategias
        print(f"\n🔍 ESTRATEGIAS DE CONVERSIÓN:")
        
        # Estrategia 1: Conversión directa
        try:
            convertidos = pd.to_numeric(df[col], errors='coerce')
            nans_originales = df[col].isna().sum()
            nans_despues = convertidos.isna().sum()
            print(f"  1. Conversión directa: {nans_despues - nans_originales} valores se volvieron NaN")
        except Exception as e:
            print(f"  1. Error en conversión directa: {e}")
        
        # Estrategia 2: Limpiar espacios y caracteres especiales
        try:
            limpiado = df[col].astype(str).str.strip()
            convertidos_limpio = pd.to_numeric(limpiado, errors='coerce')
            nans_limpio = convertidos_limpio.isna().sum()
            print(f"  2. Limpiando espacios: {nans_limpio - nans_originales} valores se volvieron NaN")
        except Exception as e:
            print(f"  2. Error limpiando espacios: {e}")
        
        # Estrategia 3: Reemplazar valores específicos
        try:
            reemplazado = df[col].replace(['-', '--', '?', 'N/A', 'n/a'], np.nan)
            convertidos_reemplazado = pd.to_numeric(reemplazado, errors='coerce')
            nans_reemplazado = convertidos_reemplazado.isna().sum()
            print(f"  3. Reemplazando valores especiales: {nans_reemplazado - nans_originales} valores se volvieron NaN")
        except Exception as e:
            print(f"  3. Error reemplazando valores: {e}")
        
        resultados[col] = {
            'valores_unicos': len(valores_unicos),
            'valores_numericos': valores_numericos,
            'valores_problematicos': valores_problematicos,
            'total_registros': len(df),
            'nans_originales': df[col].isna().sum()
        }
    
    return resultados

# Función específica para encontrar patrones raros
def encontrar_patrones_raros(df, columna):
    """
    Encuentra patrones específicos en una columna
    """
    print(f"\n🔍 PATRONES ESPECÍFICOS EN '{columna}':")
    
    valores = df[columna].dropna().astype(str)
    
    # Patrones comunes de valores problemáticos
    patrones = {
        'guiones': valores.str.contains(r'^-+$', regex=True).sum(),
        'solo_espacios': valores.str.strip().eq('').sum(),
        'caracteres_especiales': valores.str.contains(r'[^\w\s\.]', regex=True).sum(),
        'muy_largos': (valores.str.len() > 10).sum(),
        'contienen_letras': valores.str.contains(r'[a-zA-Z]', regex=True).sum(),
        'multiples_puntos': valores.str.contains(r'\..*\.', regex=True).sum(),
    }
    
    for patron, count in patrones.items():
        if count > 0:
            print(f"  {patron}: {count} casos")

# Función para generar reporte completo
def reporte_inconsistencias_completo(df):
    """
    Genera un reporte completo de inconsistencias
    """
    print("🚀 INICIANDO ANÁLISIS DE INCONSISTENCIAS EN DATOS ICFES")
    print("="*70)
    
    # Información general del dataset
    print(f"📊 INFORMACIÓN GENERAL:")
    print(f"  Dimensiones: {df.shape}")
    print(f"  Columnas objeto: {len(df.select_dtypes(include=['object']).columns)}")
    print(f"  Memoria utilizada: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
    
    # Buscar columnas sospechosas de ser numéricas
    columnas_objeto = df.select_dtypes(include=["object"]).columns
    columnas_sospechosas = []
    
    for col in columnas_objeto:
        # Si la mayoría de valores únicos son números pequeños, es sospechoso
        valores_unicos = df[col].dropna().unique()
        if len(valores_unicos) < 20:  # Pocas categorías
            try:
                numericos = [float(str(v).strip()) for v in valores_unicos if str(v).strip() not in ['-', '--', '?', 'N/A', 'n/a']]
                if len(numericos) > len(valores_unicos) * 0.7:  # Más del 70% son numéricos
                    columnas_sospechosas.append(col)
            except:
                pass
    
    print(f"\n🎯 COLUMNAS SOSPECHOSAS DE SER NUMÉRICAS:")
    print(f"  {columnas_sospechosas}")
    
    # Análizar cada columna sospechosa
    resultados = identificar_inconsistencias_numericas(df, columnas_sospechosas)
    
    return resultados

# %%
# EJEMPLO DE USO:
resultados = reporte_inconsistencias_completo(icfes)
# Out:
# 🚀 INICIANDO ANÁLISIS DE INCONSISTENCIAS EN DATOS ICFES
# ======================================================================
# 📊 INFORMACIÓN GENERAL:
#   Dimensiones: (546212, 82)
#   Columnas objeto: 60
#   Memoria utilizada: 2025.79 MB
#
# 🎯 COLUMNAS SOSPECHOSAS DE SER NUMÉRICAS:
#   ['ESTU_NSE_INDIVIDUAL']
#
# ==================================================
# ANALIZANDO COLUMNA: ESTU_NSE_INDIVIDUAL
# ==================================================
# Valores únicos: 6
# Valores numéricos: 4
# Valores problemáticos: 1
#
# ⚠️  VALORES PROBLEMÁTICOS ENCONTRADOS:
#   '-' (tipo: str) - Aparece 4 veces
#
# ✅ Valores numéricos encontrados:
#   Rango: 1 - 4
#
# 🔍 ESTRATEGIAS DE CONVERSIÓN:
#   1. Conversión directa: 4 valores se volvieron NaN
#   2. Limpiando espacios: 4 valores se volvieron NaN
#   3. Reemplazando valores especiales: 4 valores se volvieron NaN

# %% [markdown]
# # 2. LIMPIEZA DE DATOS

# %% [markdown]
# ##
#
# 1. **Renombrar y eliminar variables**
# 2. **Estandarizar la escritura de las categorías**
# 3. **Normalización variable categórica**: Unificar niveles similares (ej: "Si"/"Sí"/"YES" → "Si")
# 4. **Tratamiento de variables categóricas de alta cardinalidad**: Agrupar categorías poco frecuentes o similares
# 5. **Validación y corrección de tipos de datos**: Asegurar que variables numéricas no estén como texto
# 6. **Eliminación de registros duplicados**: Identificar y manejar duplicados exactos
# 7. **Validación de integridad para variable objetivo**: Asegurar valores consistentes, lógicos y dentro de rangos esperados
# 8. **Eliminacion de Filas con muchos NA**: Verificar la cantidad de NA tolerables por filas reduciendo la cantidad de filas perdidas pensando en una imputación futura

# %% [markdown]
# ## 1. ELIMINAR VARIABLES INÚTILES

# %%
eliminar_col = ["PERIODO", "ESTU_TIPODOCUMENTO", "COLE_NOMBRE_ESTABLECIMIENTO", "ESTU_CONSECUTIVO", 'ESTU_PAIS_RESIDE', 
               "ESTU_ESTUDIANTE", "ESTU_COD_RESIDE_DEPTO", "ESTU_COD_RESIDE_MCPIO", "COLE_CODIGO_ICFES", 'COLE_BILINGUE', 
               "COLE_COD_DANE_ESTABLECIMIENTO", "COLE_COD_DANE_SEDE", "COLE_COD_MCPIO_UBICACION", 'COLE_CARACTER',
               "COLE_COD_DEPTO_UBICACION","ESTU_COD_DEPTO_PRESENTACION","ESTU_COD_DEPTO_PRESENTACION", 'ESTU_PRIVADO_LIBERTAD',
               "COLE_NOMBRE_SEDE", "ESTU_COD_MCPIO_PRESENTACION", "ESTU_ESTADOINVESTIGACION", "ESTU_GENERACION-E"]

icfes = icfes.drop(columns=eliminar_col)

# %% [markdown]
# ### 1.1 RENOMBRAR VARIABLES

# %%
### Renombramos las variables
icfes.columns = ["nacionalidad", "genero", "fecha_nac", "pertenece_etnia", "etnia_estudiante", "dpto_est_reside", 
                 "mpio_est_reside", "estrato_casa", "num_personas_casa", "num_cuartos_casa", "nivel_edu_padre", 
                 "nivel_edu_madre", "actividad_madre", "actividad_padre", "internet", "tv", "computador", "lavadora", 
                 "microndas", "carro", "moto", "consola", "num_libros", "freq_leche_derivados", "freq_carne_pescado_similares",
                 "freq_cereales_frutos_legumbres", "situacion_economica_casa", "tiempo_lectura", "tiempo_internet", 
                 "horas_trabajo_semanal", "tipo_remuneracion", "colegio_genero", "colegio_naturaleza", "colegio_calendario", 
                 "colegio_caracter", "colegio_area", "colegio_jornada", "colegio_mpio", "colegio_dpto", 
                 "est_mpio_presento_examen", "est_dpto_presento_examen", "puntaje_lectura", "percentil_lectura", 
                 "nivel_lectura", "puntaje_matematicas", "percentil_matematicas", "nivel_matematicas", "puntaje_naturales", 
                 "percentil_naturales", "nivel_naturales", "puntaje_sociales", "percentil_sociales", "nivel_sociales", 
                 "puntaje_ingles", "percentil_ingles", "nivel_ingles", "puntaje_global", "percentil_global", "inse_estudiante", 
                 "nse_estudiante", "nse_colegio"]

icfes.head(4)
# Out:
#   nacionalidad genero   fecha_nac pertenece_etnia etnia_estudiante  \
# 0     COLOMBIA      M  18/02/2002              No                -
# 1     COLOMBIA      M  28/06/2003              No                -
# 2     COLOMBIA      M   2/06/2001              No                -
# 3     COLOMBIA      M  26/04/2002              Si          Ninguno
#
#   dpto_est_reside      mpio_est_reside estrato_casa num_personas_casa  \
# 0       MAGDALENA            SANTA ANA    Estrato 3             5 a 6
# 1          BOGOTÁ          BOGOTÁ D.C.    Estrato 3           9 o más
# 2         BOLIVAR  CARTAGENA DE INDIAS    Estrato 1             5 a 6
# 3          BOGOTÁ          BOGOTÁ D.C.    Estrato 3             3 a 4
#
#   num_cuartos_casa                     nivel_edu_padre  \
# 0            Cinco      Educación profesional completa
# 1             Tres      Técnica o tecnológica completa
# 2              Dos  Secundaria (Bachillerato) completa
# 3              Dos                 Primaria incompleta
#
#                       nivel_edu_madre  \
# 0  Secundaria (Bachillerato) completa
# 1      Técnica o tecnológica completa
# 2  Secundaria (Bachillerato) completa
# 3  Secundaria (Bachillerato) completa
#
#                                      actividad_madre  \
# 0                                          No aplica
# 1  Trabaja por cuenta propia (por ejemplo plomero...
# 2       Es vendedor o trabaja en atención al público
# 3                                          No aplica
#
#                                      actividad_padre internet  tv computador  \
# 0          Trabaja en el hogar, no trabaja o estudia       Si  Si         No
# 1  Es dueño de un negocio pequeño (tiene pocos em...       Si  Si         Si
# 2       Es vendedor o trabaja en atención al público       No  Si         No
# 3  Es dueño de un negocio pequeño (tiene pocos em...       No  No         Si
#
#   lavadora microndas carro moto consola         num_libros  \
# 0       Si        Si    No   No      No  MÁS DE 100 LIBROS
# 1       Si        Si    Si   No      No  MÁS DE 100 LIBROS
# 2       Si        No    No   No      No    26 A 100 LIBROS
# 3       No        No    No   No      No     11 A 25 LIBROS
#
#           freq_leche_derivados freq_carne_pescado_similares  \
# 0       1 o 2 veces por semana       3 a 5 veces por semana
# 1  Todos o casi todos los días       3 a 5 veces por semana
# 2  Todos o casi todos los días  Todos o casi todos los días
# 3  Todos o casi todos los días  Todos o casi todos los días
#
#   freq_cereales_frutos_legumbres situacion_economica_casa  \
# 0   Nunca o rara vez comemos eso                     Peor
# 1         1 o 2 veces por semana                    Mejor
# 2         3 a 5 veces por semana                    Igual
# 3         3 a 5 veces por semana                    Igual
#
#           tiempo_lectura        tiempo_internet horas_trabajo_semanal  \
# 0  Entre 30 y 60 minutos  Entre 30 y 60 minutos     Menos de 10 horas
# 1  Entre 30 y 60 minutos  Entre 30 y 60 minutos     Menos de 10 horas
# 2  Entre 30 y 60 minutos         Más de 3 horas                     0
# 3     30 minutos o menos  Entre 30 y 60 minutos       Más de 30 horas
#
#   tipo_remuneracion colegio_genero colegio_naturaleza colegio_calendario  \
# 0   Si, en efectivo          MIXTO            OFICIAL                  A
# 1   Si, en efectivo          MIXTO         NO OFICIAL                  A
# 2   Si, en efectivo          MIXTO            OFICIAL                  A
# 3   Si, en efectivo          MIXTO            OFICIAL                  A
#
#   colegio_caracter colegio_area colegio_jornada         colegio_mpio  \
# 0                S       URBANO          MAÑANA            SANTA ANA
# 1                S       URBANO        COMPLETA          BOGOTÁ D.C.
# 2                S       URBANO          MAÑANA  CARTAGENA DE INDIAS
# 3                S       URBANO          MAÑANA          BOGOTÁ D.C.
#
#   colegio_dpto est_mpio_presento_examen est_dpto_presento_examen  \
# 0    MAGDALENA                SANTA ANA                MAGDALENA
# 1       BOGOTÁ              BOGOTÁ D.C.                   BOGOTÁ
# 2      BOLIVAR      CARTAGENA DE INDIAS                  BOLIVAR
# 3       BOGOTÁ              BOGOTÁ D.C.                   BOGOTÁ
#
#    puntaje_lectura  percentil_lectura  nivel_lectura  puntaje_matematicas  \
# 0               47                 33              2                   48
# 1               60                 76              3                   65
# 2               66                 91              4                   57
# 3               62                 81              3                   54
#
#    percentil_matematicas  nivel_matematicas  puntaje_naturales  \
# 0                     42                  2                 37
# 1                     88                  3                 54
# 2                     70                  3                 41
# 3                     60                  3                 61
#
#    percentil_naturales  nivel_naturales  puntaje_sociales  percentil_sociales  \
# 0                   15                1                30                   8
# 1                   71                2                59                  83
# 2                   29                2                74                  99
# 3                   87                3                73                  99
#
#    nivel_sociales  puntaje_ingles  percentil_ingles nivel_ingles  \
# 0               1           54.00                67           A1
# 1               3           63.00                88           A2
# 2               4           64.00                89           A2
# 3               4           53.00                67           A1
#
#    puntaje_global percentil_global      inse_estudiante nse_estudiante  \
# 0             208               25  509.421.557.404.314              2
# 1             299               83   59.767.864.431.576              3
# 2             299               84  507.642.383.644.749              2
# 3             309               88  457.791.353.123.516              2
#
#    nse_colegio
# 0         2.00
# 1         4.00
# 2         3.00
# 3         3.00

# %% [markdown]
# ## 2. ESTANDARIZAR CATEGORÍAS DE VARIABLES

# %%
nom_propio_cat = ["nacionalidad", "dpto_est_reside", "mpio_est_reside", "num_libros", "colegio_genero", "colegio_naturaleza",
                  "colegio_caracter", "colegio_area", "colegio_jornada", "colegio_mpio", "colegio_dpto", "est_mpio_presento_examen", 
                  "est_dpto_presento_examen"]

icfes[nom_propio_cat] = icfes[nom_propio_cat].apply(lambda x: x.str.title() if x.dtype == "object" else x)
icfes.head(4)
# Out:
#   nacionalidad genero   fecha_nac pertenece_etnia etnia_estudiante  \
# 0     Colombia      M  18/02/2002              No                -
# 1     Colombia      M  28/06/2003              No                -
# 2     Colombia      M   2/06/2001              No                -
# 3     Colombia      M  26/04/2002              Si          Ninguno
#
#   dpto_est_reside      mpio_est_reside estrato_casa num_personas_casa  \
# 0       Magdalena            Santa Ana    Estrato 3             5 a 6
# 1          Bogotá          Bogotá D.C.    Estrato 3           9 o más
# 2         Bolivar  Cartagena De Indias    Estrato 1             5 a 6
# 3          Bogotá          Bogotá D.C.    Estrato 3             3 a 4
#
#   num_cuartos_casa                     nivel_edu_padre  \
# 0            Cinco      Educación profesional completa
# 1             Tres      Técnica o tecnológica completa
# 2              Dos  Secundaria (Bachillerato) completa
# 3              Dos                 Primaria incompleta
#
#                       nivel_edu_madre  \
# 0  Secundaria (Bachillerato) completa
# 1      Técnica o tecnológica completa
# 2  Secundaria (Bachillerato) completa
# 3  Secundaria (Bachillerato) completa
#
#                                      actividad_madre  \
# 0                                          No aplica
# 1  Trabaja por cuenta propia (por ejemplo plomero...
# 2       Es vendedor o trabaja en atención al público
# 3                                          No aplica
#
#                                      actividad_padre internet  tv computador  \
# 0          Trabaja en el hogar, no trabaja o estudia       Si  Si         No
# 1  Es dueño de un negocio pequeño (tiene pocos em...       Si  Si         Si
# 2       Es vendedor o trabaja en atención al público       No  Si         No
# 3  Es dueño de un negocio pequeño (tiene pocos em...       No  No         Si
#
#   lavadora microndas carro moto consola         num_libros  \
# 0       Si        Si    No   No      No  Más De 100 Libros
# 1       Si        Si    Si   No      No  Más De 100 Libros
# 2       Si        No    No   No      No    26 A 100 Libros
# 3       No        No    No   No      No     11 A 25 Libros
#
#           freq_leche_derivados freq_carne_pescado_similares  \
# 0       1 o 2 veces por semana       3 a 5 veces por semana
# 1  Todos o casi todos los días       3 a 5 veces por semana
# 2  Todos o casi todos los días  Todos o casi todos los días
# 3  Todos o casi todos los días  Todos o casi todos los días
#
#   freq_cereales_frutos_legumbres situacion_economica_casa  \
# 0   Nunca o rara vez comemos eso                     Peor
# 1         1 o 2 veces por semana                    Mejor
# 2         3 a 5 veces por semana                    Igual
# 3         3 a 5 veces por semana                    Igual
#
#           tiempo_lectura        tiempo_internet horas_trabajo_semanal  \
# 0  Entre 30 y 60 minutos  Entre 30 y 60 minutos     Menos de 10 horas
# 1  Entre 30 y 60 minutos  Entre 30 y 60 minutos     Menos de 10 horas
# 2  Entre 30 y 60 minutos         Más de 3 horas                     0
# 3     30 minutos o menos  Entre 30 y 60 minutos       Más de 30 horas
#
#   tipo_remuneracion colegio_genero colegio_naturaleza colegio_calendario  \
# 0   Si, en efectivo          Mixto            Oficial                  A
# 1   Si, en efectivo          Mixto         No Oficial                  A
# 2   Si, en efectivo          Mixto            Oficial                  A
# 3   Si, en efectivo          Mixto            Oficial                  A
#
#   colegio_caracter colegio_area colegio_jornada         colegio_mpio  \
# 0                S       Urbano          Mañana            Santa Ana
# 1                S       Urbano        Completa          Bogotá D.C.
# 2                S       Urbano          Mañana  Cartagena De Indias
# 3                S       Urbano          Mañana          Bogotá D.C.
#
#   colegio_dpto est_mpio_presento_examen est_dpto_presento_examen  \
# 0    Magdalena                Santa Ana                Magdalena
# 1       Bogotá              Bogotá D.C.                   Bogotá
# 2      Bolivar      Cartagena De Indias                  Bolivar
# 3       Bogotá              Bogotá D.C.                   Bogotá
#
#    puntaje_lectura  percentil_lectura  nivel_lectura  puntaje_matematicas  \
# 0               47                 33              2                   48
# 1               60                 76              3                   65
# 2               66                 91              4                   57
# 3               62                 81              3                   54
#
#    percentil_matematicas  nivel_matematicas  puntaje_naturales  \
# 0                     42                  2                 37
# 1                     88                  3                 54
# 2                     70                  3                 41
# 3                     60                  3                 61
#
#    percentil_naturales  nivel_naturales  puntaje_sociales  percentil_sociales  \
# 0                   15                1                30                   8
# 1                   71                2                59                  83
# 2                   29                2                74                  99
# 3                   87                3                73                  99
#
#    nivel_sociales  puntaje_ingles  percentil_ingles nivel_ingles  \
# 0               1           54.00                67           A1
# 1               3           63.00                88           A2
# 2               4           64.00                89           A2
# 3               4           53.00                67           A1
#
#    puntaje_global percentil_global      inse_estudiante nse_estudiante  \
# 0             208               25  509.421.557.404.314              2
# 1             299               83   59.767.864.431.576              3
# 2             299               84  507.642.383.644.749              2
# 3             309               88  457.791.353.123.516              2
#
#    nse_colegio
# 0         2.00
# 1         4.00
# 2         3.00
# 3         3.00

# %% [markdown]
# ## 3. NORMALIZACIÓN DE VARIABLE CATEGÓRICA

# %% [markdown]
# ### 3.1 REEMPLAZAR EL SÍMBOLO "-" POR VALORES NAN

# %%
### Cambiando el simbolo "-" por NaN para poder imputar después
# Lista para almacenar las columnas que contienen "-"
columnas_con_guion = [col for col in icfes.columns if "-" in icfes[col].astype(str).unique()]
print(columnas_con_guion)  # 🔍 Muestra las columnas que contienen "-"

for col in columnas_con_guion:
    icfes[col] = icfes[col].replace({"-": np.nan})
# Out:
# ['genero', 'pertenece_etnia', 'etnia_estudiante', 'estrato_casa', 'num_personas_casa', 'num_cuartos_casa', 'nivel_edu_padre', 'nivel_edu_madre', 'actividad_madre', 'actividad_padre', 'internet', 'tv', 'computador', 'lavadora', 'microndas', 'carro', 'moto', 'consola', 'num_libros', 'freq_leche_derivados', 'freq_carne_pescado_similares', 'freq_cereales_frutos_legumbres', 'situacion_economica_casa', 'tiempo_lectura', 'tiempo_internet', 'horas_trabajo_semanal', 'tipo_remuneracion', 'percentil_global', 'inse_estudiante', 'nse_estudiante']

# %%
### Insertando NA's
icfes["genero"] = icfes["genero"].replace({'M': 'Masculino', 'F': 'Femenino'})

# Verificar los valores después del reemplazo
print(icfes["genero"].value_counts(dropna=False))  # Muestra también los NaN
# Out:
# genero
# Femenino     295994
# Masculino    250097
# NaN             121
# Name: count, dtype: int64

# %% [markdown]
# ### 3.2 VARIABLES DEL ESTUDIANTE

# %%
icfes.sample(4)
# Out:
#        nacionalidad     genero   fecha_nac pertenece_etnia etnia_estudiante  \
# 252788     Colombia  Masculino  19/08/2002              No              NaN
# 496413     Colombia   Femenino   1/09/2002              No              NaN
# 418620     Colombia   Femenino  26/02/2003              No              NaN
# 65316      Colombia   Femenino  31/10/2002              No              NaN
#
#        dpto_est_reside mpio_est_reside estrato_casa num_personas_casa  \
# 252788       Antioquia        Medellín    Estrato 3             3 a 4
# 496413          Bogotá     Bogotá D.C.    Estrato 2             1 a 2
# 418620           Valle       Andalucía    Estrato 1             1 a 2
# 65316        Atlantico        Ponedera    Estrato 2             3 a 4
#
#        num_cuartos_casa                       nivel_edu_padre  \
# 252788             Tres        Educación profesional completa
# 496413              Dos        Técnica o tecnológica completa
# 418620              Dos  Secundaria (Bachillerato) incompleta
# 65316              Tres      Educación profesional incompleta
#
#                            nivel_edu_madre  \
# 252788      Educación profesional completa
# 496413      Técnica o tecnológica completa
# 418620  Secundaria (Bachillerato) completa
# 65316       Educación profesional completa
#
#                                           actividad_madre  \
# 252788  Trabaja como profesional (por ejemplo médico, ...
# 496413  Tiene un trabajo de tipo auxiliar administrati...
# 418620  Tiene un trabajo de tipo auxiliar administrati...
# 65316   Es operario de máquinas o conduce vehículos (t...
#
#                                           actividad_padre internet  tv  \
# 252788  Trabaja como profesional (por ejemplo médico, ...       Si  Si
# 496413  Tiene un trabajo de tipo auxiliar administrati...       No  No
# 418620  Tiene un trabajo de tipo auxiliar administrati...       No  Si
# 65316   Trabaja como profesional (por ejemplo médico, ...       Si  Si
#
#        computador lavadora microndas carro moto consola      num_libros  \
# 252788         Si       Si        Si    Si   No      No  11 A 25 Libros
# 496413         No       Si        No    No   Si      No  11 A 25 Libros
# 418620         Si       No        Si    No   No      No   0 A 10 Libros
# 65316          Si       Si        Si    No   No      No  11 A 25 Libros
#
#                 freq_leche_derivados freq_carne_pescado_similares  \
# 252788   Todos o casi todos los días  Todos o casi todos los días
# 496413        1 o 2 veces por semana       1 o 2 veces por semana
# 418620        3 a 5 veces por semana  Todos o casi todos los días
# 65316   Nunca o rara vez comemos eso  Todos o casi todos los días
#
#        freq_cereales_frutos_legumbres situacion_economica_casa  \
# 252788    Todos o casi todos los días                    Igual
# 496413         3 a 5 veces por semana                    Igual
# 418620    Todos o casi todos los días                    Igual
# 65316          1 o 2 veces por semana                    Igual
#
#                tiempo_lectura        tiempo_internet horas_trabajo_semanal  \
# 252788     30 minutos o menos  Entre 30 y 60 minutos                     0
# 496413  Entre 30 y 60 minutos     No Navega Internet                     0
# 418620      Entre 1 y 2 horas  Entre 30 y 60 minutos                     0
# 65316   Entre 30 y 60 minutos  Entre 30 y 60 minutos     Menos de 10 horas
#
#        tipo_remuneracion colegio_genero colegio_naturaleza colegio_calendario  \
# 252788                No          Mixto            Oficial                  A
# 496413                No          Mixto         No Oficial                  A
# 418620                No          Mixto            Oficial                  A
# 65316                 No          Mixto            Oficial                  A
#
#        colegio_caracter colegio_area colegio_jornada  colegio_mpio  \
# 252788                S       Urbano          Mañana      Medellín
# 496413                S       Urbano        Completa   Bogotá D.C.
# 418620                S       Urbano          Mañana     Andalucía
# 65316                 S       Urbano           Unica  Barranquilla
#
#        colegio_dpto est_mpio_presento_examen est_dpto_presento_examen  \
# 252788    Antioquia                 Medellín                Antioquia
# 496413       Bogotá              Bogotá D.C.                   Bogotá
# 418620        Valle                Andalucía                    Valle
# 65316     Atlantico             Barranquilla                Atlantico
#
#         puntaje_lectura  percentil_lectura  nivel_lectura  \
# 252788               57                 66              3
# 496413               62                 82              3
# 418620               62                 82              3
# 65316                61                 79              3
#
#         puntaje_matematicas  percentil_matematicas  nivel_matematicas  \
# 252788                   66                     90                  3
# 496413                   52                     53                  3
# 418620                   54                     62                  3
# 65316                    57                     71                  3
#
#         puntaje_naturales  percentil_naturales  nivel_naturales  \
# 252788                 47                   49                2
# 496413                 47                   46                2
# 418620                 44                   36                2
# 65316                  56                   75                3
#
#         puntaje_sociales  percentil_sociales  nivel_sociales  puntaje_ingles  \
# 252788                53                  71               2           55.00
# 496413                52                  67               2           49.00
# 418620                55                  75               2           56.00
# 65316                 42                  41               2           54.00
#
#         percentil_ingles nivel_ingles  puntaje_global percentil_global  \
# 252788                70           A1             278               73
# 496413                54           A1             265               64
# 418620                73           A1             270               68
# 65316                 69           A1             270               68
#
#             inse_estudiante nse_estudiante  nse_colegio
# 252788  719.784.123.610.725              4         3.00
# 496413  478.646.117.712.175              2         3.00
# 418620  513.643.903.389.014              3         3.00
# 65316   585.309.488.469.755              3         3.00

# %%
icfes['nse_estudiante'].value_counts(dropna=False)
# Out:
# nse_estudiante
# 2      197566
# 3      193431
# 1       94455
# 4       43715
# NaN     17045
# Name: count, dtype: int64

# %%
icfes['nse_estudiante'] = icfes['nse_estudiante'].astype('float64')

# %%
icfes["pertenece_etnia"].value_counts().sort_index()
# Out:
# pertenece_etnia
# No    506074
# Si     39761
# Name: count, dtype: int64

# %%
icfes["etnia_estudiante"].value_counts(dropna = False).sort_index()
# Out:
# etnia_estudiante
# Arhuaco                              97
# Cancuamo                            156
# Comunidad afrodescendiente        19534
# Comunidades Rom (Gitanas)            13
# Cubeo                               117
# Emberá                             1153
# Guambiano                           173
# Huitoto                              92
# Inga                                222
# Ninguno                            4442
# Otro grupo étnico minoritario      3150
# Paez                               1891
# Palenquero                           74
# Pasto                              1537
# Pijao                               703
# Raizal                              382
# Sikuani                             267
# Tucano                               33
# Wayúu                              2692
# Zenú                               3281
# NaN                              506203
# Name: count, dtype: int64

# %%
icfes["etnia_estudiante"] = icfes["etnia_estudiante"].replace({
    np.nan: "No",
    'Comunidad afrodescendiente': 'Afro',
    'Comunidades Rom (Gitanas)': 'Gitano',
    'Ninguno': 'No',
    'Otro grupo étnico minoritario': 'Otra'
    })

icfes["etnia_estudiante"].value_counts(dropna = False).sort_index()
# Out:
# etnia_estudiante
# Afro           19534
# Arhuaco           97
# Cancuamo         156
# Cubeo            117
# Emberá          1153
# Gitano            13
# Guambiano        173
# Huitoto           92
# Inga             222
# No            510645
# Otra            3150
# Paez            1891
# Palenquero        74
# Pasto           1537
# Pijao            703
# Raizal           382
# Sikuani          267
# Tucano            33
# Wayúu           2692
# Zenú            3281
# Name: count, dtype: int64

# %%
# Convertir la columna a string primero para asegurar que podemos manipular el texto
icfes['inse_estudiante'] = icfes['inse_estudiante'].astype(str)

# Eliminar puntos y caracteres no numéricos
icfes['inse_estudiante'] = icfes['inse_estudiante'].str.replace('.', '')
icfes['inse_estudiante'] = icfes['inse_estudiante'].str.extract('(\d+)', expand=False)

# Tomar los primeros 4 dígitos y formatear como XX.XX
icfes['inse_estudiante'] = icfes['inse_estudiante'].str[:4]
icfes['inse_estudiante'] = icfes['inse_estudiante'].str[:2] + '.' + icfes['inse_estudiante'].str[2:]

# Convertir a float
icfes['inse_estudiante'] = pd.to_numeric(icfes['inse_estudiante'], errors='coerce')

# %%
def codificacion_dummy(df):
    # Renombrar columnas
    df.rename(columns={'nacionalidad': 'colombiano', 'etnia_estudiante': 'etnia'}, inplace=True)
    
    # Codificación binaria
    df['colombiano'] = (df['colombiano'] == 'Colombia').astype(int)
    df['etnia'] = (df['etnia'] != 'No').astype(int)
    
    return df

# %% [markdown]
# ### 3.3 VARIABLES DEL HOGAR

# %%
icfes["estrato_casa"].value_counts(dropna = False).sort_index()
# Out:
# estrato_casa
# Estrato 1      159977
# Estrato 2      188314
# Estrato 3      108692
# Estrato 4       25810
# Estrato 5        8024
# Estrato 6        3711
# Sin Estrato     17177
# NaN             34507
# Name: count, dtype: int64

# %%
icfes["estrato_casa"] = icfes["estrato_casa"].replace({
    'Estrato 1': 1,
    'Estrato 2': 2,
    'Estrato 3': 3,
    'Estrato 4': 4,
    'Estrato 5': 5,
    'Estrato 6': 6,
    'Sin Estrato': np.nan,
    })

# %%
icfes["num_personas_casa"].value_counts()
# Out:
# num_personas_casa
# 3 a 4      257604
# 5 a 6      170028
# 7 a 8       44984
# 1 a 2       39843
# 9 o más     17760
# Name: count, dtype: int64

# %%
icfes["num_personas_casa"] = icfes["num_personas_casa"].replace({
    '1 a 2': "Hogar tradicional", 
    '3 a 4': "Hogar tradicional", 
    '5 a 6': "Hogar grande", 
    '7 a 8': "Más de 1 hogar", 
    '9 o más': "Más de 1 hogar"
})

icfes["num_personas_casa"].value_counts()
# Out:
# num_personas_casa
# Hogar tradicional    297447
# Hogar grande         170028
# Más de 1 hogar        62744
# Name: count, dtype: int64

# %%
icfes['num_cuartos_casa'].value_counts(dropna = False)
# Out:
# num_cuartos_casa
# Tres          207232
# Dos           189042
# Cuatro         70635
# Uno            28276
# Cinco          21966
# NaN            17158
# Seis o mas     11903
# Name: count, dtype: int64

# %%
icfes['num_cuartos_casa'] = icfes['num_cuartos_casa'].replace({
    'Uno': 1,
    'Dos': 2,
    'Tres': 3,
    'Cuatro': 4,
    'Cinco': 5,
    'Seis o mas': 6
})

icfes['num_cuartos_casa'].value_counts(dropna = False).sort_values(ascending=True)
# Out:
# num_cuartos_casa
# 6.00     11903
# NaN      17158
# 5.00     21966
# 1.00     28276
# 4.00     70635
# 2.00    189042
# 3.00    207232
# Name: count, dtype: int64

# %%
icfes["internet"].value_counts(dropna = False)
# Out:
# internet
# Si     314042
# No     201199
# NaN     30971
# Name: count, dtype: int64

# %%
icfes["computador"].value_counts(dropna = False)
# Out:
# computador
# Si     295409
# No     233827
# NaN     16976
# Name: count, dtype: int64

# %%
icfes["lavadora"].value_counts(dropna = False)
# Out:
# lavadora
# Si     405542
# No     123912
# NaN     16758
# Name: count, dtype: int64

# %%
icfes["microndas"].value_counts(dropna = False)
# Out:
# microndas
# No     280967
# Si     247694
# NaN     17551
# Name: count, dtype: int64

# %%
icfes["carro"].value_counts(dropna = False)
# Out:
# carro
# No     401388
# Si     126735
# NaN     18089
# Name: count, dtype: int64

# %%
icfes["moto"].value_counts(dropna = False)
# Out:
# moto
# No     308054
# Si     221051
# NaN     17107
# Name: count, dtype: int64

# %%
icfes["consola"].value_counts(dropna = False)
# Out:
# consola
# No     410475
# Si     117642
# NaN     18095
# Name: count, dtype: int64

# %%
columnas = ['pertenece_etnia', 'internet', 'tv', 'computador', 'lavadora', 'microndas', 'carro', 'moto', 'consola']

for col in columnas:
    icfes[col] = np.where(icfes[col] == 'Si', 1, 0)

# %%
icfes.sample(6)
# Out:
#        nacionalidad     genero   fecha_nac  pertenece_etnia etnia_estudiante  \
# 70799      Colombia  Masculino  17/06/2001                0               No
# 55746      Colombia  Masculino  21/10/2002                0               No
# 80240      Colombia  Masculino  24/08/2002                1             Zenú
# 283977     Colombia   Femenino  24/10/2002                0               No
# 421666     Colombia   Femenino   3/07/2003                0               No
# 420859     Colombia   Femenino   2/03/2003                0               No
#
#        dpto_est_reside      mpio_est_reside  estrato_casa  num_personas_casa  \
# 70799             Meta        Villavicencio           NaN  Hogar tradicional
# 55746           Bogotá          Bogotá D.C.          2.00  Hogar tradicional
# 80240          Cordoba               Lorica          4.00       Hogar grande
# 283977           Huila             La Plata          2.00  Hogar tradicional
# 421666       Atlantico         Barranquilla          2.00       Hogar grande
# 420859         Bolivar  Cartagena De Indias          3.00  Hogar tradicional
#
#         num_cuartos_casa                       nivel_edu_padre  \
# 70799               2.00                                   NaN
# 55746               2.00  Secundaria (Bachillerato) incompleta
# 80240               3.00    Secundaria (Bachillerato) completa
# 283977              3.00    Secundaria (Bachillerato) completa
# 421666              2.00        Educación profesional completa
# 420859              3.00                               No sabe
#
#                            nivel_edu_madre  \
# 70799                                  NaN
# 55746       Técnica o tecnológica completa
# 80240   Secundaria (Bachillerato) completa
# 283977  Secundaria (Bachillerato) completa
# 421666      Educación profesional completa
# 420859      Educación profesional completa
#
#                                           actividad_madre  \
# 70799                                             No sabe
# 55746   Trabaja por cuenta propia (por ejemplo plomero...
# 80240           Trabaja en el hogar, no trabaja o estudia
# 283977  Tiene un trabajo de tipo auxiliar administrati...
# 421666  Trabaja como profesional (por ejemplo médico, ...
# 420859                                            No sabe
#
#                                           actividad_padre  internet  tv  \
# 70799           Trabaja en el hogar, no trabaja o estudia         0   0
# 55746   Tiene un trabajo de tipo auxiliar administrati...         1   1
# 80240           Trabaja en el hogar, no trabaja o estudia         0   0
# 283977  Tiene un trabajo de tipo auxiliar administrati...         1   1
# 421666  Tiene un trabajo de tipo auxiliar administrati...         1   1
# 420859  Trabaja como profesional (por ejemplo médico, ...         1   1
#
#         computador  lavadora  microndas  carro  moto  consola      num_libros  \
# 70799            1         0          0      0     0        0             NaN
# 55746            1         1          1      1     1        1   0 A 10 Libros
# 80240            0         1          0      0     0        0  11 A 25 Libros
# 283977           1         1          1      1     1        0   0 A 10 Libros
# 421666           1         1          1      0     1        0   0 A 10 Libros
# 420859           0         1          0      0     0        0   0 A 10 Libros
#
#                freq_leche_derivados freq_carne_pescado_similares  \
# 70799                           NaN                          NaN
# 55746   Todos o casi todos los días       3 a 5 veces por semana
# 80240        1 o 2 veces por semana       3 a 5 veces por semana
# 283977       1 o 2 veces por semana  Todos o casi todos los días
# 421666  Todos o casi todos los días  Todos o casi todos los días
# 420859       3 a 5 veces por semana  Todos o casi todos los días
#
#        freq_cereales_frutos_legumbres situacion_economica_casa  \
# 70799                             NaN                    Igual
# 55746          3 a 5 veces por semana                    Igual
# 80240    Nunca o rara vez comemos eso                    Igual
# 283977    Todos o casi todos los días                    Igual
# 421666         1 o 2 veces por semana                     Peor
# 420859         1 o 2 veces por semana                    Igual
#
#                     tiempo_lectura        tiempo_internet  \
# 70799                          NaN                    NaN
# 55746   No leo por entretenimiento      Entre 1 y 3 horas
# 80240               Más de 2 horas         Más de 3 horas
# 283977       Entre 30 y 60 minutos  Entre 30 y 60 minutos
# 421666           Entre 1 y 2 horas      Entre 1 y 3 horas
# 420859       Entre 30 y 60 minutos         Más de 3 horas
#
#        horas_trabajo_semanal tipo_remuneracion colegio_genero  \
# 70799      Menos de 10 horas                No          Mixto
# 55746                      0                No          Mixto
# 80240                      0                No          Mixto
# 283977                     0                No          Mixto
# 421666                     0                No          Mixto
# 420859                     0                No          Mixto
#
#        colegio_naturaleza colegio_calendario colegio_caracter colegio_area  \
# 70799             Oficial                  A                S       Urbano
# 55746             Oficial                  A                N       Urbano
# 80240             Oficial                  A                S        Rural
# 283977            Oficial                  A                S       Urbano
# 421666         No Oficial                  A                S       Urbano
# 420859            Oficial                  A                S       Urbano
#
#        colegio_jornada         colegio_mpio colegio_dpto  \
# 70799            Noche        Villavicencio         Meta
# 55746           Mañana          Bogotá D.C.       Bogotá
# 80240           Mañana               Lorica      Cordoba
# 283977           Unica             La Plata        Huila
# 421666          Mañana         Barranquilla    Atlantico
# 420859           Unica  Cartagena De Indias      Bolivar
#
#        est_mpio_presento_examen est_dpto_presento_examen  puntaje_lectura  \
# 70799             Villavicencio                     Meta               33
# 55746               Bogotá D.C.                   Bogotá               49
# 80240                    Lorica                  Cordoba               34
# 283977                 La Plata                    Huila               63
# 421666             Barranquilla                Atlantico               67
# 420859      Cartagena De Indias                  Bolivar               55
#
#         percentil_lectura  nivel_lectura  puntaje_matematicas  \
# 70799                   4              1                   35
# 55746                  38              2                   51
# 80240                   4              1                   35
# 283977                 84              3                   50
# 421666                 93              4                   49
# 420859                 59              3                   45
#
#         percentil_matematicas  nivel_matematicas  puntaje_naturales  \
# 70799                      10                  1                 30
# 55746                      50                  3                 53
# 80240                      10                  1                 47
# 283977                     49                  2                 57
# 421666                     46                  2                 60
# 420859                     34                  2                 48
#
#         percentil_naturales  nivel_naturales  puntaje_sociales  \
# 70799                     4                1                37
# 55746                    68                2                44
# 80240                    46                2                27
# 283977                   79                3                58
# 421666                   85                3                69
# 420859                   51                2                48
#
#         percentil_sociales  nivel_sociales  puntaje_ingles  percentil_ingles  \
# 70799                   27               1           35.00                14
# 55746                   46               2           55.00                72
# 80240                    4               1           33.00                11
# 283977                  82               3           56.00                74
# 421666                  97               3           77.00                98
# 420859                  58               2           37.00                20
#
#        nivel_ingles  puntaje_global percentil_global  inse_estudiante  \
# 70799            A-             169                6            44.62
# 55746            A1             248               54            59.88
# 80240            A-             178                9            43.35
# 283977           A1             285               76            58.31
# 421666           B1             312               89            64.47
# 420859           A-             240               48            53.12
#
#         nse_estudiante  nse_colegio
# 70799             2.00         2.00
# 55746             3.00         2.00
# 80240             2.00         2.00
# 283977            3.00         2.00
# 421666            4.00         3.00
# 420859            3.00         2.00

# %% [markdown]
# ### 3.4 VARIABLES DE EDUCACIÓN Y TRABAJO EN EL HOGAR

# %%
icfes["nivel_edu_madre"].value_counts(dropna = False).sort_index(ascending = True)
# Out:
# nivel_edu_madre
# Educación profesional completa           54474
# Educación profesional incompleta         12384
# Ninguno                                  12762
# No Aplica                                 1081
# No sabe                                   9275
# Postgrado                                10805
# Primaria completa                        53441
# Primaria incompleta                      80062
# Secundaria (Bachillerato) completa      136286
# Secundaria (Bachillerato) incompleta     76353
# Técnica o tecnológica completa           52949
# Técnica o tecnológica incompleta         15973
# NaN                                      30367
# Name: count, dtype: int64

# %%
icfes["nivel_edu_madre"] = icfes["nivel_edu_madre"].replace({
  'Educación profesional completa': 'Profesional',
  'Educación profesional incompleta': 'Profesional Inc',
  'Ninguno': 'Ninguna',
  'No Aplica': 'No aplica',
  'No sabe': np.nan,
  'Primaria completa': 'Primaria',
  'Primaria incompleta': 'Primaria Inc',
  'Secundaria (Bachillerato) completa': 'Bachiller',
  'Secundaria (Bachillerato) incompleta': 'Bachiller Inc',
  'Técnica o tecnológica completa': 'Tecnico/Tecnologo',
  'Técnica o tecnológica incompleta': 'Tecnico/Tecnologo Inc'
})

icfes["nivel_edu_madre"].value_counts(dropna = False).sort_index(ascending = True)
# Out:
# nivel_edu_madre
# Bachiller                136286
# Bachiller Inc             76353
# Ninguna                   12762
# No aplica                  1081
# Postgrado                 10805
# Primaria                  53441
# Primaria Inc              80062
# Profesional               54474
# Profesional Inc           12384
# Tecnico/Tecnologo         52949
# Tecnico/Tecnologo Inc     15973
# NaN                       39642
# Name: count, dtype: int64

# %%
icfes["nivel_edu_padre"].value_counts(dropna = False).sort_index(ascending = True)
# Out:
# nivel_edu_padre
# Educación profesional completa           46404
# Educación profesional incompleta         10150
# Ninguno                                  20106
# No Aplica                                 6849
# No sabe                                  32104
# Postgrado                                 9437
# Primaria completa                        54141
# Primaria incompleta                     101387
# Secundaria (Bachillerato) completa      117488
# Secundaria (Bachillerato) incompleta     71295
# Técnica o tecnológica completa           35367
# Técnica o tecnológica incompleta         10957
# NaN                                      30527
# Name: count, dtype: int64

# %%
icfes["nivel_edu_padre"] = icfes["nivel_edu_padre"].replace({
  'Educación profesional completa': 'Profesional',
  'Educación profesional incompleta': 'Profesional Inc',
  'Ninguno': 'Ninguna',
  'No Aplica': 'No aplica',
  'No sabe': np.nan,
  'Primaria completa': 'Primaria',
  'Primaria incompleta': 'Primaria Inc',
  'Secundaria (Bachillerato) completa': 'Bachiller',
  'Secundaria (Bachillerato) incompleta': 'Bachiller Inc',
  'Técnica o tecnológica completa': 'Tecnico/Tecnologo',
  'Técnica o tecnológica incompleta': 'Tecnico/Tecnologo Inc'
})

icfes["nivel_edu_padre"].value_counts(dropna = False).sort_index(ascending = True)
# Out:
# nivel_edu_padre
# Bachiller                117488
# Bachiller Inc             71295
# Ninguna                   20106
# No aplica                  6849
# Postgrado                  9437
# Primaria                  54141
# Primaria Inc             101387
# Profesional               46404
# Profesional Inc           10150
# Tecnico/Tecnologo         35367
# Tecnico/Tecnologo Inc     10957
# NaN                       62631
# Name: count, dtype: int64

# %%
icfes["actividad_madre"].value_counts(dropna = False).sort_index()
# Out:
# actividad_madre
# Es agricultor, pesquero o jornalero                                                                     78187
# Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial                            12943
# Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc    44247
# Es operario de máquinas o conduce vehículos (taxita, chofer)                                            56948
# Es vendedor o trabaja en atención al público                                                            31413
# No aplica                                                                                               49029
# No sabe                                                                                                 44249
# Pensionado                                                                                              13006
# Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)                  22596
# Trabaja como personal de limpieza, mantenimiento, seguridad o construcción                              39965
# Trabaja como profesional (por ejemplo médico, abogado, ingeniero)                                       41203
# Trabaja en el hogar, no trabaja o estudia                                                               33173
# Trabaja por cuenta propia (por ejemplo plomero, electricista)                                           60949
# NaN                                                                                                     18304
# Name: count, dtype: int64

# %%
# Definir el mapeo de categorías
mapeo = {
    # Profesionales y Directivos
    'Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial': 'Directivos',
    'Trabaja como profesional (por ejemplo médico, abogado, ingeniero)': 'Profesionales',

    # Trabajadores Independientes y Pequeños Empresarios
    'Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc': 'Microempresario',
    'Trabaja por cuenta propia (por ejemplo plomero, electricista)': 'Trabajador Independiente',

    # Trabajadores Operativos y de Servicios
    'Es operario de máquinas o conduce vehículos (taxita, chofer)': 'Trabajadores Operativos',
    'Es vendedor o trabaja en atención al público': 'Trabajadores Operativos',
    'Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)': 'Trabajadores Operativos',
    'Trabaja como personal de limpieza, mantenimiento, seguridad o construcción': 'Trabajadores Operativos',
    
    # Trabajadores del Sector Primario
    'Es agricultor, pesquero o jornalero': 'Sector Primario',
    
    # Sin Actividad Laboral Remunerada
    'Trabaja en el hogar, no trabaja o estudia': 'Sin Actividad Remunerada',
    'Pensionado': 'Pensionado',
    
    # Datos No Disponibles
    'No aplica': 'No Aplica',
    'No sabe': 'Sin Información'
}

# Aplicar la reclasificación directamente a cada columna
icfes['actividad_madre'] = icfes['actividad_madre'].map(mapeo)
icfes['actividad_padre'] = icfes['actividad_padre'].map(mapeo)

# %%
icfes['actividad_padre'].value_counts(dropna = False)
# Out:
# actividad_padre
# Sin Actividad Remunerada    213377
# Trabajadores Operativos     140178
# Microempresario              48129
# Profesionales                41939
# No Aplica                    27451
# NaN                          17503
# Sector Primario              17017
# Trabajador Independiente     16550
# Sin Información              11704
# Directivos                    8707
# Pensionado                    3657
# Name: count, dtype: int64

# %%
icfes.head(4)
# Out:
#   nacionalidad     genero   fecha_nac  pertenece_etnia etnia_estudiante  \
# 0     Colombia  Masculino  18/02/2002                0               No
# 1     Colombia  Masculino  28/06/2003                0               No
# 2     Colombia  Masculino   2/06/2001                0               No
# 3     Colombia  Masculino  26/04/2002                1               No
#
#   dpto_est_reside      mpio_est_reside  estrato_casa  num_personas_casa  \
# 0       Magdalena            Santa Ana          3.00       Hogar grande
# 1          Bogotá          Bogotá D.C.          3.00     Más de 1 hogar
# 2         Bolivar  Cartagena De Indias          1.00       Hogar grande
# 3          Bogotá          Bogotá D.C.          3.00  Hogar tradicional
#
#    num_cuartos_casa    nivel_edu_padre    nivel_edu_madre  \
# 0              5.00        Profesional          Bachiller
# 1              3.00  Tecnico/Tecnologo  Tecnico/Tecnologo
# 2              2.00          Bachiller          Bachiller
# 3              2.00       Primaria Inc          Bachiller
#
#             actividad_madre           actividad_padre  internet  tv  \
# 0                 No Aplica  Sin Actividad Remunerada         1   1
# 1  Trabajador Independiente           Microempresario         1   1
# 2   Trabajadores Operativos   Trabajadores Operativos         0   1
# 3                 No Aplica           Microempresario         0   0
#
#    computador  lavadora  microndas  carro  moto  consola         num_libros  \
# 0           0         1          1      0     0        0  Más De 100 Libros
# 1           1         1          1      1     0        0  Más De 100 Libros
# 2           0         1          0      0     0        0    26 A 100 Libros
# 3           1         0          0      0     0        0     11 A 25 Libros
#
#           freq_leche_derivados freq_carne_pescado_similares  \
# 0       1 o 2 veces por semana       3 a 5 veces por semana
# 1  Todos o casi todos los días       3 a 5 veces por semana
# 2  Todos o casi todos los días  Todos o casi todos los días
# 3  Todos o casi todos los días  Todos o casi todos los días
#
#   freq_cereales_frutos_legumbres situacion_economica_casa  \
# 0   Nunca o rara vez comemos eso                     Peor
# 1         1 o 2 veces por semana                    Mejor
# 2         3 a 5 veces por semana                    Igual
# 3         3 a 5 veces por semana                    Igual
#
#           tiempo_lectura        tiempo_internet horas_trabajo_semanal  \
# 0  Entre 30 y 60 minutos  Entre 30 y 60 minutos     Menos de 10 horas
# 1  Entre 30 y 60 minutos  Entre 30 y 60 minutos     Menos de 10 horas
# 2  Entre 30 y 60 minutos         Más de 3 horas                     0
# 3     30 minutos o menos  Entre 30 y 60 minutos       Más de 30 horas
#
#   tipo_remuneracion colegio_genero colegio_naturaleza colegio_calendario  \
# 0   Si, en efectivo          Mixto            Oficial                  A
# 1   Si, en efectivo          Mixto         No Oficial                  A
# 2   Si, en efectivo          Mixto            Oficial                  A
# 3   Si, en efectivo          Mixto            Oficial                  A
#
#   colegio_caracter colegio_area colegio_jornada         colegio_mpio  \
# 0                S       Urbano          Mañana            Santa Ana
# 1                S       Urbano        Completa          Bogotá D.C.
# 2                S       Urbano          Mañana  Cartagena De Indias
# 3                S       Urbano          Mañana          Bogotá D.C.
#
#   colegio_dpto est_mpio_presento_examen est_dpto_presento_examen  \
# 0    Magdalena                Santa Ana                Magdalena
# 1       Bogotá              Bogotá D.C.                   Bogotá
# 2      Bolivar      Cartagena De Indias                  Bolivar
# 3       Bogotá              Bogotá D.C.                   Bogotá
#
#    puntaje_lectura  percentil_lectura  nivel_lectura  puntaje_matematicas  \
# 0               47                 33              2                   48
# 1               60                 76              3                   65
# 2               66                 91              4                   57
# 3               62                 81              3                   54
#
#    percentil_matematicas  nivel_matematicas  puntaje_naturales  \
# 0                     42                  2                 37
# 1                     88                  3                 54
# 2                     70                  3                 41
# 3                     60                  3                 61
#
#    percentil_naturales  nivel_naturales  puntaje_sociales  percentil_sociales  \
# 0                   15                1                30                   8
# 1                   71                2                59                  83
# 2                   29                2                74                  99
# 3                   87                3                73                  99
#
#    nivel_sociales  puntaje_ingles  percentil_ingles nivel_ingles  \
# 0               1           54.00                67           A1
# 1               3           63.00                88           A2
# 2               4           64.00                89           A2
# 3               4           53.00                67           A1
#
#    puntaje_global percentil_global  inse_estudiante  nse_estudiante  \
# 0             208               25            50.94            2.00
# 1             299               83            59.76            3.00
# 2             299               84            50.76            2.00
# 3             309               88            45.77            2.00
#
#    nse_colegio
# 0         2.00
# 1         4.00
# 2         3.00
# 3         3.00

# %%
icfes["horas_trabajo_semanal"].value_counts()
# Out:
# horas_trabajo_semanal
# 0                      354503
# Menos de 10 horas       97913
# Entre 11 y 20 horas     41729
# Más de 30 horas         19907
# Entre 21 y 30 horas     15270
# Name: count, dtype: int64

# %%
icfes["horas_trabajo_semanal"] = icfes["horas_trabajo_semanal"].replace({'0': 'No Trabaja',
        'Menos de 10 horas': 'Trabajo Ocasional',
        'Entre 11 y 20 horas': 'Tiempo Parcial Reducido',
        'Entre 21 y 30 horas': 'Medio Tiempo',
        'Más de 30 horas': 'Tiempo Completo'
})

icfes["horas_trabajo_semanal"].value_counts()
# Out:
# horas_trabajo_semanal
# No Trabaja                 354503
# Trabajo Ocasional           97913
# Tiempo Parcial Reducido     41729
# Tiempo Completo             19907
# Medio Tiempo                15270
# Name: count, dtype: int64

# %%
icfes["tipo_remuneracion"].value_counts()
# Out:
# tipo_remuneracion
# No                           377436
# Si, en efectivo              134786
# Si, en especie                 8530
# Si, en efectivo y especie      7361
# Name: count, dtype: int64

# %%
icfes["tipo_remuneracion"] = icfes["tipo_remuneracion"].replace({'No': 'Sin Remuneración',
        'Si, en efectivo': 'Remuneración Monetaria',
        'Si, en especie': 'Remuneración No Monetaria',
        'Si, en efectivo y especie': 'Remuneración Mixta'})

icfes["tipo_remuneracion"].value_counts()
# Out:
# tipo_remuneracion
# Sin Remuneración             377436
# Remuneración Monetaria       134786
# Remuneración No Monetaria      8530
# Remuneración Mixta             7361
# Name: count, dtype: int64

# %%
# Si "horas_trabajo_semanal" es "No Trabaja", cambiar "tipo_remuneracion" a "No Aplica"
icfes.loc[icfes["horas_trabajo_semanal"] == "No Trabaja", "tipo_remuneracion"] = "No Aplica"

# %% [markdown]
# ### 3.5 VARIABLES DE ENTRETENIMIENTO

# %%
icfes.head(4)
# Out:
#   nacionalidad     genero   fecha_nac  pertenece_etnia etnia_estudiante  \
# 0     Colombia  Masculino  18/02/2002                0               No
# 1     Colombia  Masculino  28/06/2003                0               No
# 2     Colombia  Masculino   2/06/2001                0               No
# 3     Colombia  Masculino  26/04/2002                1               No
#
#   dpto_est_reside      mpio_est_reside  estrato_casa  num_personas_casa  \
# 0       Magdalena            Santa Ana          3.00       Hogar grande
# 1          Bogotá          Bogotá D.C.          3.00     Más de 1 hogar
# 2         Bolivar  Cartagena De Indias          1.00       Hogar grande
# 3          Bogotá          Bogotá D.C.          3.00  Hogar tradicional
#
#    num_cuartos_casa    nivel_edu_padre    nivel_edu_madre  \
# 0              5.00        Profesional          Bachiller
# 1              3.00  Tecnico/Tecnologo  Tecnico/Tecnologo
# 2              2.00          Bachiller          Bachiller
# 3              2.00       Primaria Inc          Bachiller
#
#             actividad_madre           actividad_padre  internet  tv  \
# 0                 No Aplica  Sin Actividad Remunerada         1   1
# 1  Trabajador Independiente           Microempresario         1   1
# 2   Trabajadores Operativos   Trabajadores Operativos         0   1
# 3                 No Aplica           Microempresario         0   0
#
#    computador  lavadora  microndas  carro  moto  consola         num_libros  \
# 0           0         1          1      0     0        0  Más De 100 Libros
# 1           1         1          1      1     0        0  Más De 100 Libros
# 2           0         1          0      0     0        0    26 A 100 Libros
# 3           1         0          0      0     0        0     11 A 25 Libros
#
#           freq_leche_derivados freq_carne_pescado_similares  \
# 0       1 o 2 veces por semana       3 a 5 veces por semana
# 1  Todos o casi todos los días       3 a 5 veces por semana
# 2  Todos o casi todos los días  Todos o casi todos los días
# 3  Todos o casi todos los días  Todos o casi todos los días
#
#   freq_cereales_frutos_legumbres situacion_economica_casa  \
# 0   Nunca o rara vez comemos eso                     Peor
# 1         1 o 2 veces por semana                    Mejor
# 2         3 a 5 veces por semana                    Igual
# 3         3 a 5 veces por semana                    Igual
#
#           tiempo_lectura        tiempo_internet horas_trabajo_semanal  \
# 0  Entre 30 y 60 minutos  Entre 30 y 60 minutos     Trabajo Ocasional
# 1  Entre 30 y 60 minutos  Entre 30 y 60 minutos     Trabajo Ocasional
# 2  Entre 30 y 60 minutos         Más de 3 horas            No Trabaja
# 3     30 minutos o menos  Entre 30 y 60 minutos       Tiempo Completo
#
#         tipo_remuneracion colegio_genero colegio_naturaleza  \
# 0  Remuneración Monetaria          Mixto            Oficial
# 1  Remuneración Monetaria          Mixto         No Oficial
# 2               No Aplica          Mixto            Oficial
# 3  Remuneración Monetaria          Mixto            Oficial
#
#   colegio_calendario colegio_caracter colegio_area colegio_jornada  \
# 0                  A                S       Urbano          Mañana
# 1                  A                S       Urbano        Completa
# 2                  A                S       Urbano          Mañana
# 3                  A                S       Urbano          Mañana
#
#           colegio_mpio colegio_dpto est_mpio_presento_examen  \
# 0            Santa Ana    Magdalena                Santa Ana
# 1          Bogotá D.C.       Bogotá              Bogotá D.C.
# 2  Cartagena De Indias      Bolivar      Cartagena De Indias
# 3          Bogotá D.C.       Bogotá              Bogotá D.C.
#
#   est_dpto_presento_examen  puntaje_lectura  percentil_lectura  nivel_lectura  \
# 0                Magdalena               47                 33              2
# 1                   Bogotá               60                 76              3
# 2                  Bolivar               66                 91              4
# 3                   Bogotá               62                 81              3
#
#    puntaje_matematicas  percentil_matematicas  nivel_matematicas  \
# 0                   48                     42                  2
# 1                   65                     88                  3
# 2                   57                     70                  3
# 3                   54                     60                  3
#
#    puntaje_naturales  percentil_naturales  nivel_naturales  puntaje_sociales  \
# 0                 37                   15                1                30
# 1                 54                   71                2                59
# 2                 41                   29                2                74
# 3                 61                   87                3                73
#
#    percentil_sociales  nivel_sociales  puntaje_ingles  percentil_ingles  \
# 0                   8               1           54.00                67
# 1                  83               3           63.00                88
# 2                  99               4           64.00                89
# 3                  99               4           53.00                67
#
#   nivel_ingles  puntaje_global percentil_global  inse_estudiante  \
# 0           A1             208               25            50.94
# 1           A2             299               83            59.76
# 2           A2             299               84            50.76
# 3           A1             309               88            45.77
#
#    nse_estudiante  nse_colegio
# 0            2.00         2.00
# 1            3.00         4.00
# 2            2.00         3.00
# 3            2.00         3.00

# %%
icfes["num_libros"].value_counts(dropna = False)
# Out:
# num_libros
# 0 A 10 Libros        207526
# 11 A 25 Libros       153968
# 26 A 100 Libros      105653
# NaN                   44652
# Más De 100 Libros     34413
# Name: count, dtype: int64

# %%
icfes["num_libros"] = icfes["num_libros"].replace({'0 A 10 Libros': '0-10', '11 A 25 Libros': '11-25',
                                                   '26 A 100 Libros': '26-100', 'Más De 100 Libros': '>100'})

icfes["num_libros"].value_counts(dropna = False)
# Out:
# num_libros
# 0-10      207526
# 11-25     153968
# 26-100    105653
# NaN        44652
# >100       34413
# Name: count, dtype: int64

# %%
icfes["tiempo_lectura"].value_counts(dropna = False)
# Out:
# tiempo_lectura
# 30 minutos o menos            199094
# Entre 30 y 60 minutos         144272
# No leo por entretenimiento     95621
# Entre 1 y 2 horas              55480
# NaN                            31735
# Más de 2 horas                 20010
# Name: count, dtype: int64

# %%
icfes["tiempo_lectura"] = icfes["tiempo_lectura"].replace({'No leo por entretenimiento': 'No lee', '30 minutos o menos': '0-30 min',
                                                           'Entre 30 y 60 minutos': '30-60 min', 'Entre 1 y 2 horas': '1-2h', 'Más de 2 horas': '>2h'})

icfes["tiempo_lectura"].value_counts(dropna = False)
# Out:
# tiempo_lectura
# 0-30 min     199094
# 30-60 min    144272
# No lee        95621
# 1-2h          55480
# NaN           31735
# >2h           20010
# Name: count, dtype: int64

# %%
icfes["tiempo_internet"].value_counts(dropna = False)
# Out:
# tiempo_internet
# Entre 1 y 3 horas        157557
# Entre 30 y 60 minutos    134383
# Más de 3 horas           100134
# 30 minutos o menos        90517
# NaN                       32924
# No Navega Internet        30697
# Name: count, dtype: int64

# %%
icfes["tiempo_internet"] = icfes["tiempo_internet"].replace({'No Navega Internet': 'Ninguno', '30 minutos o menos': 'Poco',
                                                             'Entre 30 y 60 minutos': 'Moderado', 'Entre 1 y 3 horas': 'Promedio', 'Más de 3 horas': 'Mucho'})

icfes["tiempo_internet"].value_counts(dropna = False)
# Out:
# tiempo_internet
# Promedio    157557
# Moderado    134383
# Mucho       100134
# Poco         90517
# NaN          32924
# Ninguno      30697
# Name: count, dtype: int64

# %% [markdown]
# ### 3.6 VARIABLES DE ALIMENTACIÓN

# %%
icfes.head(5)
# Out:
#   nacionalidad     genero   fecha_nac  pertenece_etnia etnia_estudiante  \
# 0     Colombia  Masculino  18/02/2002                0               No
# 1     Colombia  Masculino  28/06/2003                0               No
# 2     Colombia  Masculino   2/06/2001                0               No
# 3     Colombia  Masculino  26/04/2002                1               No
# 4     Colombia  Masculino   5/02/2002                0               No
#
#   dpto_est_reside      mpio_est_reside  estrato_casa  num_personas_casa  \
# 0       Magdalena            Santa Ana          3.00       Hogar grande
# 1          Bogotá          Bogotá D.C.          3.00     Más de 1 hogar
# 2         Bolivar  Cartagena De Indias          1.00       Hogar grande
# 3          Bogotá          Bogotá D.C.          3.00  Hogar tradicional
# 4          Bogotá          Bogotá D.C.          3.00  Hogar tradicional
#
#    num_cuartos_casa    nivel_edu_padre    nivel_edu_madre  \
# 0              5.00        Profesional          Bachiller
# 1              3.00  Tecnico/Tecnologo  Tecnico/Tecnologo
# 2              2.00          Bachiller          Bachiller
# 3              2.00       Primaria Inc          Bachiller
# 4              4.00          Bachiller      Bachiller Inc
#
#             actividad_madre           actividad_padre  internet  tv  \
# 0                 No Aplica  Sin Actividad Remunerada         1   1
# 1  Trabajador Independiente           Microempresario         1   1
# 2   Trabajadores Operativos   Trabajadores Operativos         0   1
# 3                 No Aplica           Microempresario         0   0
# 4  Sin Actividad Remunerada  Sin Actividad Remunerada         1   1
#
#    computador  lavadora  microndas  carro  moto  consola num_libros  \
# 0           0         1          1      0     0        0       >100
# 1           1         1          1      1     0        0       >100
# 2           0         1          0      0     0        0     26-100
# 3           1         0          0      0     0        0      11-25
# 4           1         1          1      0     0        0     26-100
#
#           freq_leche_derivados  freq_carne_pescado_similares  \
# 0       1 o 2 veces por semana        3 a 5 veces por semana
# 1  Todos o casi todos los días        3 a 5 veces por semana
# 2  Todos o casi todos los días   Todos o casi todos los días
# 3  Todos o casi todos los días   Todos o casi todos los días
# 4  Todos o casi todos los días  Nunca o rara vez comemos eso
#
#   freq_cereales_frutos_legumbres situacion_economica_casa tiempo_lectura  \
# 0   Nunca o rara vez comemos eso                     Peor      30-60 min
# 1         1 o 2 veces por semana                    Mejor      30-60 min
# 2         3 a 5 veces por semana                    Igual      30-60 min
# 3         3 a 5 veces por semana                    Igual       0-30 min
# 4    Todos o casi todos los días                    Mejor         No lee
#
#   tiempo_internet horas_trabajo_semanal       tipo_remuneracion  \
# 0        Moderado     Trabajo Ocasional  Remuneración Monetaria
# 1        Moderado     Trabajo Ocasional  Remuneración Monetaria
# 2           Mucho            No Trabaja               No Aplica
# 3        Moderado       Tiempo Completo  Remuneración Monetaria
# 4           Mucho       Tiempo Completo        Sin Remuneración
#
#   colegio_genero colegio_naturaleza colegio_calendario colegio_caracter  \
# 0          Mixto            Oficial                  A                S
# 1          Mixto         No Oficial                  A                S
# 2          Mixto            Oficial                  A                S
# 3          Mixto            Oficial                  A                S
# 4          Mixto            Oficial                  A                S
#
#   colegio_area colegio_jornada         colegio_mpio colegio_dpto  \
# 0       Urbano          Mañana            Santa Ana    Magdalena
# 1       Urbano        Completa          Bogotá D.C.       Bogotá
# 2       Urbano          Mañana  Cartagena De Indias      Bolivar
# 3       Urbano          Mañana          Bogotá D.C.       Bogotá
# 4       Urbano          Mañana          Bogotá D.C.       Bogotá
#
#   est_mpio_presento_examen est_dpto_presento_examen  puntaje_lectura  \
# 0                Santa Ana                Magdalena               47
# 1              Bogotá D.C.                   Bogotá               60
# 2      Cartagena De Indias                  Bolivar               66
# 3              Bogotá D.C.                   Bogotá               62
# 4              Bogotá D.C.                   Bogotá               63
#
#    percentil_lectura  nivel_lectura  puntaje_matematicas  \
# 0                 33              2                   48
# 1                 76              3                   65
# 2                 91              4                   57
# 3                 81              3                   54
# 4                 85              3                   57
#
#    percentil_matematicas  nivel_matematicas  puntaje_naturales  \
# 0                     42                  2                 37
# 1                     88                  3                 54
# 2                     70                  3                 41
# 3                     60                  3                 61
# 4                     70                  3                 55
#
#    percentil_naturales  nivel_naturales  puntaje_sociales  percentil_sociales  \
# 0                   15                1                30                   8
# 1                   71                2                59                  83
# 2                   29                2                74                  99
# 3                   87                3                73                  99
# 4                   74                2                57                  79
#
#    nivel_sociales  puntaje_ingles  percentil_ingles nivel_ingles  \
# 0               1           54.00                67           A1
# 1               3           63.00                88           A2
# 2               4           64.00                89           A2
# 3               4           53.00                67           A1
# 4               3           52.00                63           A1
#
#    puntaje_global percentil_global  inse_estudiante  nse_estudiante  \
# 0             208               25            50.94            2.00
# 1             299               83            59.76            3.00
# 2             299               84            50.76            2.00
# 3             309               88            45.77            2.00
# 4             288               78            52.91            3.00
#
#    nse_colegio
# 0         2.00
# 1         4.00
# 2         3.00
# 3         3.00
# 4         3.00

# %%
icfes["freq_leche_derivados"].value_counts()
# Out:
# freq_leche_derivados
# 1 o 2 veces por semana          170538
# Todos o casi todos los días     160798
# 3 a 5 veces por semana          133932
# Nunca o rara vez comemos eso     44252
# Name: count, dtype: int64

# %%
icfes["freq_carne_pescado_similares"].value_counts()
# Out:
# freq_carne_pescado_similares
# Todos o casi todos los días     209228
# 3 a 5 veces por semana          154432
# 1 o 2 veces por semana          124422
# Nunca o rara vez comemos eso     25600
# Name: count, dtype: int64

# %%
icfes["freq_cereales_frutos_legumbres"].value_counts()
# Out:
# freq_cereales_frutos_legumbres
# 1 o 2 veces por semana          198491
# 3 a 5 veces por semana          154261
# Todos o casi todos los días      88346
# Nunca o rara vez comemos eso     71536
# Name: count, dtype: int64

# %%
mapping = {
    'Nunca o rara vez comemos eso': 'Muy Insuficiente',
    '1 o 2 veces por semana': 'Insuficiente',
    '3 a 5 veces por semana': 'Aceptable',
    'Todos o casi todos los días': 'Óptimo'
}

cols = ["freq_leche_derivados", 
        "freq_carne_pescado_similares", 
        "freq_cereales_frutos_legumbres"]

icfes[cols] = icfes[cols].replace(mapping)
icfes.sample(8)
# Out:
#        nacionalidad     genero   fecha_nac  pertenece_etnia etnia_estudiante  \
# 229081     Colombia  Masculino  10/07/2002                0               No
# 339541     Colombia  Masculino  16/02/2004                0               No
# 91190      Colombia   Femenino  24/07/2001                0               No
# 260912     Colombia  Masculino  13/10/2002                0               No
# 419716     Colombia   Femenino  12/10/2002                0               No
# 391900     Colombia   Femenino   2/01/2002                0               No
# 182944     Colombia  Masculino   5/03/2002                0               No
# 466769     Colombia   Femenino  21/10/2002                0               No
#
#        dpto_est_reside      mpio_est_reside  estrato_casa  num_personas_casa  \
# 229081       Antioquia             Medellín          3.00  Hogar tradicional
# 339541       Antioquia                Turbo          5.00       Hogar grande
# 91190            Valle                 Cali          2.00     Más de 1 hogar
# 260912       Santander      Barrancabermeja          3.00       Hogar grande
# 419716         Quindio           Montenegro          2.00  Hogar tradicional
# 391900       Antioquia            Girardota          2.00  Hogar tradicional
# 182944         Bolivar  Cartagena De Indias          3.00  Hogar tradicional
# 466769          Bogotá          Bogotá D.C.          2.00  Hogar tradicional
#
#         num_cuartos_casa    nivel_edu_padre    nivel_edu_madre  \
# 229081              2.00      Bachiller Inc          Bachiller
# 339541              5.00           Primaria          Bachiller
# 91190               4.00            Ninguna          Bachiller
# 260912              5.00  Tecnico/Tecnologo  Tecnico/Tecnologo
# 419716              3.00           Primaria       Primaria Inc
# 391900              3.00          Bachiller          Bachiller
# 182944              1.00       Primaria Inc          Bachiller
# 466769              2.00        Profesional        Profesional
#
#                  actividad_madre           actividad_padre  internet  tv  \
# 229081  Trabajador Independiente  Trabajador Independiente         1   1
# 339541           Sector Primario  Sin Actividad Remunerada         0   1
# 91190                  No Aplica   Trabajadores Operativos         1   1
# 260912                 No Aplica   Trabajadores Operativos         1   1
# 419716  Sin Actividad Remunerada  Sin Actividad Remunerada         0   0
# 391900                 No Aplica  Sin Actividad Remunerada         1   0
# 182944           Microempresario   Trabajadores Operativos         1   0
# 466769  Trabajador Independiente   Trabajadores Operativos         1   1
#
#         computador  lavadora  microndas  carro  moto  consola num_libros  \
# 229081           0         0          1      0     0        0     26-100
# 339541           0         1          0      0     1        0      11-25
# 91190            1         1          0      0     0        1       0-10
# 260912           1         1          1      0     0        0       0-10
# 419716           1         0          1      0     1        0       >100
# 391900           0         0          0      0     1        0       0-10
# 182944           0         1          0      0     1        0       0-10
# 466769           1         1          1      0     1        0     26-100
#
#        freq_leche_derivados freq_carne_pescado_similares  \
# 229081         Insuficiente                    Aceptable
# 339541            Aceptable                    Aceptable
# 91190      Muy Insuficiente             Muy Insuficiente
# 260912            Aceptable                    Aceptable
# 419716         Insuficiente                 Insuficiente
# 391900               Óptimo                       Óptimo
# 182944         Insuficiente             Muy Insuficiente
# 466769         Insuficiente                       Óptimo
#
#        freq_cereales_frutos_legumbres situacion_economica_casa tiempo_lectura  \
# 229081                   Insuficiente                    Igual      30-60 min
# 339541                         Óptimo                    Igual       0-30 min
# 91190                Muy Insuficiente                    Igual         No lee
# 260912                      Aceptable                     Peor       0-30 min
# 419716               Muy Insuficiente                     Peor            >2h
# 391900               Muy Insuficiente                    Igual       0-30 min
# 182944                      Aceptable                     Peor       0-30 min
# 466769                   Insuficiente                    Mejor      30-60 min
#
#        tiempo_internet    horas_trabajo_semanal          tipo_remuneracion  \
# 229081            Poco               No Trabaja                  No Aplica
# 339541        Moderado               No Trabaja                  No Aplica
# 91190         Promedio               No Trabaja                  No Aplica
# 260912           Mucho  Tiempo Parcial Reducido  Remuneración No Monetaria
# 419716        Promedio               No Trabaja                  No Aplica
# 391900            Poco               No Trabaja                  No Aplica
# 182944        Promedio        Trabajo Ocasional           Sin Remuneración
# 466769        Promedio               No Trabaja                  No Aplica
#
#        colegio_genero colegio_naturaleza colegio_calendario colegio_caracter  \
# 229081          Mixto            Oficial                  A                S
# 339541          Mixto            Oficial                  A                S
# 91190           Mixto         No Oficial                  B                S
# 260912          Mixto            Oficial                  A                S
# 419716          Mixto            Oficial                  A                S
# 391900          Mixto            Oficial                  A                S
# 182944          Mixto         No Oficial                  A                S
# 466769          Mixto         No Oficial                  A                S
#
#        colegio_area colegio_jornada         colegio_mpio colegio_dpto  \
# 229081       Urbano          Mañana             Medellín    Antioquia
# 339541        Rural          Mañana                Turbo    Antioquia
# 91190        Urbano          Mañana                 Cali        Valle
# 260912       Urbano           Tarde      Barrancabermeja    Santander
# 419716       Urbano          Mañana           Montenegro      Quindio
# 391900        Rural          Mañana            Girardota    Antioquia
# 182944       Urbano           Tarde  Cartagena De Indias      Bolivar
# 466769       Urbano        Completa          Bogotá D.C.       Bogotá
#
#        est_mpio_presento_examen est_dpto_presento_examen  puntaje_lectura  \
# 229081                 Medellín                Antioquia               51
# 339541       San Pedro De Urabá                Antioquia               57
# 91190                      Cali                    Valle               51
# 260912          Barrancabermeja                Santander               51
# 419716               Montenegro                  Quindio               68
# 391900               Copacabana                Antioquia               48
# 182944      Cartagena De Indias                  Bolivar               70
# 466769              Bogotá D.C.                   Bogotá               45
#
#         percentil_lectura  nivel_lectura  puntaje_matematicas  \
# 229081                 47              3                   38
# 339541                 67              3                   49
# 91190                  46              3                   34
# 260912                 46              3                   51
# 419716                 93              4                   67
# 391900                 36              2                   42
# 182944                 97              4                   66
# 466769                 25              2                   45
#
#         percentil_matematicas  nivel_matematicas  puntaje_naturales  \
# 229081                     16                  2                 45
# 339541                     46                  2                 46
# 91190                       9                  1                 39
# 260912                     52                  3                 50
# 419716                     91                  3                 57
# 391900                     26                  2                 36
# 182944                     90                  3                 51
# 466769                     34                  2                 38
#
#         percentil_naturales  nivel_naturales  puntaje_sociales  \
# 229081                   39                2                40
# 339541                   43                2                43
# 91190                    21                1                37
# 260912                   57                2                46
# 419716                   80                3                53
# 391900                   14                1                41
# 182944                   60                2                68
# 466769                   18                1                30
#
#         percentil_sociales  nivel_sociales  puntaje_ingles  percentil_ingles  \
# 229081                  35               1           36.00                17
# 339541                  45               2           34.00                13
# 91190                   26               1           37.00                19
# 260912                  53               2           58.00                78
# 419716                  71               2           56.00                73
# 391900                  37               2           43.00                36
# 182944                  96               3           69.00                94
# 466769                   9               1           49.00                54
#
#        nivel_ingles  puntaje_global percentil_global  inse_estudiante  \
# 229081           A-             215               30            48.77
# 339541           A-             238               46            44.47
# 91190            A-             200               20            44.45
# 260912           A2             251               55            56.39
# 419716           A1             304               86            41.71
# 391900           A-             209               26            46.30
# 182944           B1             321               92            41.68
# 466769           A1             201               21            60.19
#
#         nse_estudiante  nse_colegio
# 229081            2.00         3.00
# 339541            2.00         2.00
# 91190             2.00         3.00
# 260912            3.00         3.00
# 419716            2.00         2.00
# 391900            2.00         2.00
# 182944            2.00         3.00
# 466769            3.00         3.00

# %% [markdown]
# ### 3.7 VARIABLES DE COLEGIOS

# %%
icfes.head(4)
# Out:
#   nacionalidad     genero   fecha_nac  pertenece_etnia etnia_estudiante  \
# 0     Colombia  Masculino  18/02/2002                0               No
# 1     Colombia  Masculino  28/06/2003                0               No
# 2     Colombia  Masculino   2/06/2001                0               No
# 3     Colombia  Masculino  26/04/2002                1               No
#
#   dpto_est_reside      mpio_est_reside  estrato_casa  num_personas_casa  \
# 0       Magdalena            Santa Ana          3.00       Hogar grande
# 1          Bogotá          Bogotá D.C.          3.00     Más de 1 hogar
# 2         Bolivar  Cartagena De Indias          1.00       Hogar grande
# 3          Bogotá          Bogotá D.C.          3.00  Hogar tradicional
#
#    num_cuartos_casa    nivel_edu_padre    nivel_edu_madre  \
# 0              5.00        Profesional          Bachiller
# 1              3.00  Tecnico/Tecnologo  Tecnico/Tecnologo
# 2              2.00          Bachiller          Bachiller
# 3              2.00       Primaria Inc          Bachiller
#
#             actividad_madre           actividad_padre  internet  tv  \
# 0                 No Aplica  Sin Actividad Remunerada         1   1
# 1  Trabajador Independiente           Microempresario         1   1
# 2   Trabajadores Operativos   Trabajadores Operativos         0   1
# 3                 No Aplica           Microempresario         0   0
#
#    computador  lavadora  microndas  carro  moto  consola num_libros  \
# 0           0         1          1      0     0        0       >100
# 1           1         1          1      1     0        0       >100
# 2           0         1          0      0     0        0     26-100
# 3           1         0          0      0     0        0      11-25
#
#   freq_leche_derivados freq_carne_pescado_similares  \
# 0         Insuficiente                    Aceptable
# 1               Óptimo                    Aceptable
# 2               Óptimo                       Óptimo
# 3               Óptimo                       Óptimo
#
#   freq_cereales_frutos_legumbres situacion_economica_casa tiempo_lectura  \
# 0               Muy Insuficiente                     Peor      30-60 min
# 1                   Insuficiente                    Mejor      30-60 min
# 2                      Aceptable                    Igual      30-60 min
# 3                      Aceptable                    Igual       0-30 min
#
#   tiempo_internet horas_trabajo_semanal       tipo_remuneracion  \
# 0        Moderado     Trabajo Ocasional  Remuneración Monetaria
# 1        Moderado     Trabajo Ocasional  Remuneración Monetaria
# 2           Mucho            No Trabaja               No Aplica
# 3        Moderado       Tiempo Completo  Remuneración Monetaria
#
#   colegio_genero colegio_naturaleza colegio_calendario colegio_caracter  \
# 0          Mixto            Oficial                  A                S
# 1          Mixto         No Oficial                  A                S
# 2          Mixto            Oficial                  A                S
# 3          Mixto            Oficial                  A                S
#
#   colegio_area colegio_jornada         colegio_mpio colegio_dpto  \
# 0       Urbano          Mañana            Santa Ana    Magdalena
# 1       Urbano        Completa          Bogotá D.C.       Bogotá
# 2       Urbano          Mañana  Cartagena De Indias      Bolivar
# 3       Urbano          Mañana          Bogotá D.C.       Bogotá
#
#   est_mpio_presento_examen est_dpto_presento_examen  puntaje_lectura  \
# 0                Santa Ana                Magdalena               47
# 1              Bogotá D.C.                   Bogotá               60
# 2      Cartagena De Indias                  Bolivar               66
# 3              Bogotá D.C.                   Bogotá               62
#
#    percentil_lectura  nivel_lectura  puntaje_matematicas  \
# 0                 33              2                   48
# 1                 76              3                   65
# 2                 91              4                   57
# 3                 81              3                   54
#
#    percentil_matematicas  nivel_matematicas  puntaje_naturales  \
# 0                     42                  2                 37
# 1                     88                  3                 54
# 2                     70                  3                 41
# 3                     60                  3                 61
#
#    percentil_naturales  nivel_naturales  puntaje_sociales  percentil_sociales  \
# 0                   15                1                30                   8
# 1                   71                2                59                  83
# 2                   29                2                74                  99
# 3                   87                3                73                  99
#
#    nivel_sociales  puntaje_ingles  percentil_ingles nivel_ingles  \
# 0               1           54.00                67           A1
# 1               3           63.00                88           A2
# 2               4           64.00                89           A2
# 3               4           53.00                67           A1
#
#    puntaje_global percentil_global  inse_estudiante  nse_estudiante  \
# 0             208               25            50.94            2.00
# 1             299               83            59.76            3.00
# 2             299               84            50.76            2.00
# 3             309               88            45.77            2.00
#
#    nse_colegio
# 0         2.00
# 1         4.00
# 2         3.00
# 3         3.00

# %%
icfes["colegio_genero"].value_counts(dropna = False)
# Out:
# colegio_genero
# Mixto        528780
# Femenino      13462
# Masculino      3970
# Name: count, dtype: int64

# %%
icfes["colegio_naturaleza"].value_counts(dropna = False)
# Out:
# colegio_naturaleza
# Oficial       416011
# No Oficial    130201
# Name: count, dtype: int64

# %%
icfes["colegio_calendario"] = icfes["colegio_calendario"].str.capitalize()

# %%
icfes["colegio_calendario"].value_counts(dropna = False)
# Out:
# colegio_calendario
# A       541901
# Otro      3171
# B         1140
# Name: count, dtype: int64

# %%
icfes["colegio_caracter"].value_counts(dropna = False)
# Out:
# colegio_caracter
# S    523322
# N     22890
# Name: count, dtype: int64

# %%
icfes["colegio_area"].value_counts(dropna = False)
# Out:
# colegio_area
# Urbano    460467
# Rural      85745
# Name: count, dtype: int64

# %%
icfes["colegio_jornada"].value_counts(dropna = False)
# Out:
# colegio_jornada
# Mañana      257060
# Completa     89520
# Unica        67361
# Tarde        59049
# Sabatina     39098
# Noche        34124
# Name: count, dtype: int64

# %% [markdown]
# ### 3.8 VARIABLES DE FECHA Y EDAD DE ESTUDIANTES

# %%
# 1. Corregir fechas que inician con "000"
icfes["fecha_nac"] = icfes["fecha_nac"].astype(str).str.replace(r"^000", "2", regex=True)

# 2. Convertir la columna a tipo fecha manejando distintos formatos
icfes["fecha_nac"] = pd.to_datetime(icfes["fecha_nac"], errors="coerce", dayfirst=True)

# 3. Extraer solo el año
icfes["año_nacimiento"] = icfes["fecha_nac"].dt.year

# 4. Contar cuántas veces aparece cada año
conteo_fechas = icfes["año_nacimiento"].value_counts().sort_index()

# 5. Crear la variable Edad
icfes["edad"] = 2019 - icfes["año_nacimiento"]

# 6. Quitamos los decimales
icfes["edad"] = icfes["edad"].round(0).astype("Int64")

# Mostrar resultados
print(conteo_fechas)
# Out:
# año_nacimiento
# 1900.00    1851
# 1910.00       1
# 1936.00       1
# 1940.00       2
# 1943.00       2
#            ...
# 2015.00       1
# 2016.00       3
# 2017.00       7
# 2018.00      25
# 2019.00      97
# Name: count, Length: 81, dtype: int64

# %%
icfes["edad"].value_counts(dropna = False)
# Out:
# edad
# 17     217955
# 18     114088
# 16     110771
# 19      51158
# 20      16152
#         ...
# 76          2
# 74          1
# 4           1
# 83          1
# 109         1
# Name: count, Length: 82, dtype: Int64

# %%
plt.figure(figsize = (12, 10))
sns.countplot(x = 'edad', data = icfes)
sns.set_theme(style = 'white', context = 'talk')

plt.title('Distribución de Edades')
plt.xlabel('Edades', fontsize = 12)
plt.ylabel('Cantidad', fontsize = 12)
plt.xticks(rotation = 45, ha = 'right')
plt.tight_layout()
plt.show()

# %%
## Nos quedamos solo con las edades entre 14 y 79 años
icfes = icfes[(icfes["edad"] >= 14) & (icfes["edad"] <= 79)]

# %%
# Definir los límites de los bins
bins = list(range(15, 81, 5))  # De 15 a 80 en pasos de 5

# Crear etiquetas para los bins
labels = [f"{bins[i]}-{bins[i+1]-1}" for i in range(len(bins)-1)]

# Crear la nueva variable 'grupo_edad'
icfes["grupo_edad"] = pd.cut(icfes["edad"], bins=bins, labels=labels, right=False)

# Verificar distribución
print(icfes["grupo_edad"].value_counts(dropna = False))
# Out:
# grupo_edad
# 15-19    499012
# 20-24     29831
# 25-29      5603
# 30-34      3285
# 35-39      2249
# 40-44      1401
# 45-49       897
# 50-54       632
# 55-59       377
# NaN         184
# 60-64       159
# 65-69        73
# 70-74        23
# 75-79         8
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12, 10))
sns.countplot(x = 'grupo_edad', data = icfes)
sns.set_theme(style = 'white', context = 'talk')

plt.title('Distribución de Edades')
plt.xlabel('Edades', fontsize = 12)
plt.ylabel('Cantidad', fontsize = 12)
plt.xticks(rotation = 45, ha = 'right')
plt.tight_layout()
plt.show()

# %%
icfes["grupo_edad"].value_counts(dropna = False)
# Out:
# grupo_edad
# 15-19    499012
# 20-24     29831
# 25-29      5603
# 30-34      3285
# 35-39      2249
# 40-44      1401
# 45-49       897
# 50-54       632
# 55-59       377
# NaN         184
# 60-64       159
# 65-69        73
# 70-74        23
# 75-79         8
# Name: count, dtype: int64

# %%
# Crear la variable
icfes['presento_fuera_edad'] = (icfes['edad'] > 19).astype(int)

# Verificar distribución
print("Distribución de la variable:")
print(icfes['presento_fuera_edad'].value_counts())
print('------------------------------------------------------')
print(f"\nPorcentaje fuera de edad: {icfes['presento_fuera_edad'].mean():.2%}")
print('------------------------------------------------------')

# Verificar algunos casos
print("\nVerificación manual:")
print(icfes[['edad', 'presento_fuera_edad']].head(10))

# Estadísticas por grupo
print("\nEdad promedio por grupo:")
print(icfes.groupby('presento_fuera_edad')['edad'].agg(['count', 'mean', 'min', 'max']))
# Out:
# Distribución de la variable:
# presento_fuera_edad
# 0    499196
# 1     44538
# Name: count, dtype: int64
# ------------------------------------------------------
#
# Porcentaje fuera de edad: 8.19%
# ------------------------------------------------------
#
# Verificación manual:
#    edad  presento_fuera_edad
# 0    17                    0
# 1    16                    0
# 2    18                    0
# 3    17                    0
# 4    17                    0
# 5    20                    1
# 6    17                    0
# 7    17                    0
# 8    17                    0
# 9    17                    0
#
# Edad promedio por grupo:
#                       count  mean  min  max
# presento_fuera_edad
# 0                    499196 17.19   14   19
# 1                     44538 25.44   20   79

# %% [markdown]
# ### 3.9 VARIABLES DE DATOS GEOGRÁFICOS

# %%
icfes['colegio_dpto'].value_counts(dropna = False)
# Out:
# colegio_dpto
# Bogotá             82432
# Antioquia          73878
# Valle              38503
# Cundinamarca       36846
# Atlantico          32034
# Santander          25614
# Bolivar            25266
# Cordoba            19864
# Nariño             16893
# Boyaca             16689
# Magdalena          16479
# Tolima             16276
# Norte Santander    15872
# Huila              14034
# Cauca              13862
# Cesar              13209
# Meta               12493
# Sucre              10868
# Risaralda          10716
# Caldas             10330
# La Guajira          8803
# Quindio             6425
# Casanare            5927
# Choco               4849
# Caqueta             4648
# Putumayo            4034
# Arauca              3330
# Guaviare            1011
# Amazonas             817
# San Andres           616
# Vichada              496
# Vaupes               352
# Guainia              268
# Name: count, dtype: int64

# %%
# Crear un diccionario con la asignación de departamentos a regiones
departamento_a_region = {
    # Región Andina
    'Antioquia': 'Andina', 'Boyaca': 'Andina', 'Caldas': 'Andina', 'Cundinamarca': 'Andina',
    'Huila': 'Andina', 'Norte Santander': 'Andina', 'Quindio': 'Andina',
    'Risaralda': 'Andina', 'Santander': 'Andina', 'Tolima': 'Andina', 'Bogotá': 'Andina',

    # Región Caribe
    'Atlantico': 'Caribe', 'Bolivar': 'Caribe', 'Cesar': 'Caribe', 'Cordoba': 'Caribe',
    'La Guajira': 'Caribe', 'Magdalena': 'Caribe', 'Sucre': 'Caribe','San Andres': 'Caribe',

    # Región Pacífica
    'Cauca': 'Pacífica', 'Choco': 'Pacífica', 'Nariño': 'Pacífica', 'Valle': 'Pacífica',

    # Región Orinoquía
    'Meta': 'Orinoquía', 'Arauca': 'Orinoquía', 'Casanare': 'Orinoquía', 'Vichada': 'Orinoquía',

    # Región Amazónica
    'Caqueta': 'Amazónica', 'Putumayo': 'Amazónica', 'Amazonas': 'Amazónica',
    'Guainia': 'Amazónica', 'Guaviare': 'Amazónica', 'Vaupes': 'Amazónica'
}

# Crear la nueva variable 'region' en el dataframe ICFES
icfes['region'] = icfes['colegio_dpto'].map(departamento_a_region)

# Verificar si hay departamentos sin asignación
print(icfes[icfes['region'].isna()]['colegio_dpto'].unique())
# Out:
# []

# %% [markdown]
# ## 4 BORRAR VARIABLES y FILAS

# %%
var_eli = ["est_mpio_presento_examen", "est_dpto_presento_examen", 
           "fecha_nac", "año_nacimiento", 'pertenece_etnia', "dpto_est_reside", "mpio_est_reside"]

icfes = icfes.drop(columns=var_eli)
icfes.sample(4)
# Out:
#        nacionalidad     genero etnia_estudiante  estrato_casa  \
# 423172     Colombia   Femenino               No          2.00
# 489732     Colombia   Femenino               No          3.00
# 156521     Colombia   Femenino               No          1.00
# 245342     Colombia  Masculino               No          1.00
#
#         num_personas_casa  num_cuartos_casa nivel_edu_padre nivel_edu_madre  \
# 423172  Hogar tradicional              2.00       Bachiller     Profesional
# 489732       Hogar grande              2.00     Profesional       Bachiller
# 156521     Más de 1 hogar              6.00    Primaria Inc         Ninguna
# 245342       Hogar grande               NaN   Bachiller Inc   Bachiller Inc
#
#                  actividad_madre           actividad_padre  internet  tv  \
# 423172   Trabajadores Operativos             Profesionales         1   0
# 489732   Trabajadores Operativos             Profesionales         0   0
# 156521  Trabajador Independiente           Sector Primario         0   1
# 245342   Trabajadores Operativos  Sin Actividad Remunerada         0   0
#
#         computador  lavadora  microndas  carro  moto  consola num_libros  \
# 423172           1         1          0      0     0        0       0-10
# 489732           0         1          0      0     0        0     26-100
# 156521           0         1          0      1     1        1       0-10
# 245342           0         1          0      0     0        0       0-10
#
#        freq_leche_derivados freq_carne_pescado_similares  \
# 423172         Insuficiente                    Aceptable
# 489732         Insuficiente                       Óptimo
# 156521     Muy Insuficiente             Muy Insuficiente
# 245342            Aceptable                    Aceptable
#
#        freq_cereales_frutos_legumbres situacion_economica_casa tiempo_lectura  \
# 423172                      Aceptable                    Igual      30-60 min
# 489732               Muy Insuficiente                    Igual           1-2h
# 156521               Muy Insuficiente                    Mejor       0-30 min
# 245342                   Insuficiente                    Igual       0-30 min
#
#        tiempo_internet horas_trabajo_semanal tipo_remuneracion colegio_genero  \
# 423172        Promedio            No Trabaja         No Aplica          Mixto
# 489732        Moderado            No Trabaja         No Aplica          Mixto
# 156521         Ninguno       Tiempo Completo  Sin Remuneración          Mixto
# 245342            Poco            No Trabaja         No Aplica          Mixto
#
#        colegio_naturaleza colegio_calendario colegio_caracter colegio_area  \
# 423172            Oficial                  A                S       Urbano
# 489732            Oficial                  A                S       Urbano
# 156521            Oficial                  A                S       Urbano
# 245342            Oficial                  A                S       Urbano
#
#        colegio_jornada colegio_mpio colegio_dpto  puntaje_lectura  \
# 423172           Unica     Medellín    Antioquia               50
# 489732           Unica     Montería      Cordoba               55
# 156521        Sabatina      Caicedo    Antioquia               39
# 245342          Mañana       Ibagué       Tolima               45
#
#         percentil_lectura  nivel_lectura  puntaje_matematicas  \
# 423172                 41              2                   45
# 489732                 59              3                   33
# 156521                 12              2                   34
# 245342                 25              2                   36
#
#         percentil_matematicas  nivel_matematicas  puntaje_naturales  \
# 423172                     33                  2                 44
# 489732                      7                  1                 45
# 156521                      9                  1                 30
# 245342                     13                  2                 50
#
#         percentil_naturales  nivel_naturales  puntaje_sociales  \
# 423172                   39                2                47
# 489732                   42                2                37
# 156521                    3                1                26
# 245342                   57                2                52
#
#         percentil_sociales  nivel_sociales  puntaje_ingles  percentil_ingles  \
# 423172                  54               2           48.00                51
# 489732                  27               1           36.00                17
# 156521                   2               1           35.00                15
# 245342                  68               2           35.00                13
#
#        nivel_ingles  puntaje_global percentil_global  inse_estudiante  \
# 423172           A1             233               43            52.71
# 489732           A-             210               27            46.60
# 156521           A-             162                4            34.92
# 245342           A-             225               37            42.09
#
#         nse_estudiante  nse_colegio  edad grupo_edad  presento_fuera_edad  \
# 423172            3.00         2.00    16      15-19                    0
# 489732            2.00         2.00    16      15-19                    0
# 156521            1.00         2.00    17      15-19                    0
# 245342            2.00         2.00    17      15-19                    0
#
#         region
# 423172  Andina
# 489732  Caribe
# 156521  Andina
# 245342  Andina

# %%
# Analizar el porcentaje de missing values
missing_analysis = pd.DataFrame({
    'Column': icfes.columns,
    'Missing_Count': icfes.isnull().sum(),
    'Missing_Percentage': (icfes.isnull().sum() / len(icfes)) * 100
}).sort_values('Missing_Percentage', ascending=False)

print(missing_analysis)
# Out:
#                                                         Column  Missing_Count  \
# nivel_edu_padre                                nivel_edu_padre          62323
# estrato_casa                                      estrato_casa          51438
# num_libros                                          num_libros          44454
# nivel_edu_madre                                nivel_edu_madre          39468
# freq_leche_derivados                      freq_leche_derivados          36512
# freq_cereales_frutos_legumbres  freq_cereales_frutos_legumbres          33415
# tiempo_internet                                tiempo_internet          32770
# freq_carne_pescado_similares      freq_carne_pescado_similares          32377
# tiempo_lectura                                  tiempo_lectura          31591
# actividad_madre                                actividad_madre          18225
# situacion_economica_casa              situacion_economica_casa          17803
# actividad_padre                                actividad_padre          17427
# num_cuartos_casa                              num_cuartos_casa          17085
# nse_estudiante                                  nse_estudiante          16975
# inse_estudiante                                inse_estudiante          16975
# horas_trabajo_semanal                    horas_trabajo_semanal          16817
# tipo_remuneracion                            tipo_remuneracion          16655
# num_personas_casa                            num_personas_casa          15927
# grupo_edad                                          grupo_edad            184
# genero                                                  genero            102
# nse_colegio                                        nse_colegio             44
# puntaje_ingles                                  puntaje_ingles             18
# percentil_global                              percentil_global             18
# internet                                              internet              0
# consola                                                consola              0
# nacionalidad                                      nacionalidad              0
# etnia_estudiante                              etnia_estudiante              0
# microndas                                            microndas              0
# tv                                                          tv              0
# lavadora                                              lavadora              0
# computador                                          computador              0
# moto                                                      moto              0
# carro                                                    carro              0
# colegio_genero                                  colegio_genero              0
# colegio_naturaleza                          colegio_naturaleza              0
# puntaje_lectura                                puntaje_lectura              0
# percentil_lectura                            percentil_lectura              0
# colegio_calendario                          colegio_calendario              0
# colegio_caracter                              colegio_caracter              0
# colegio_area                                      colegio_area              0
# colegio_jornada                                colegio_jornada              0
# colegio_mpio                                      colegio_mpio              0
# colegio_dpto                                      colegio_dpto              0
# percentil_naturales                        percentil_naturales              0
# puntaje_naturales                            puntaje_naturales              0
# nivel_matematicas                            nivel_matematicas              0
# percentil_matematicas                    percentil_matematicas              0
# puntaje_matematicas                        puntaje_matematicas              0
# nivel_lectura                                    nivel_lectura              0
# percentil_sociales                          percentil_sociales              0
# nivel_naturales                                nivel_naturales              0
# puntaje_global                                  puntaje_global              0
# nivel_ingles                                      nivel_ingles              0
# percentil_ingles                              percentil_ingles              0
# nivel_sociales                                  nivel_sociales              0
# puntaje_sociales                              puntaje_sociales              0
# edad                                                      edad              0
# presento_fuera_edad                        presento_fuera_edad              0
# region                                                  region              0
#
#                                 Missing_Percentage
# nivel_edu_padre                              11.46
# estrato_casa                                  9.46
# num_libros                                    8.18
# nivel_edu_madre                               7.26
# freq_leche_derivados                          6.72
# freq_cereales_frutos_legumbres                6.15
# tiempo_internet                               6.03
# freq_carne_pescado_similares                  5.95
# tiempo_lectura                                5.81
# actividad_madre                               3.35
# situacion_economica_casa                      3.27
# actividad_padre                               3.21
# num_cuartos_casa                              3.14
# nse_estudiante                                3.12
# inse_estudiante                               3.12
# horas_trabajo_semanal                         3.09
# tipo_remuneracion                             3.06
# num_personas_casa                             2.93
# grupo_edad                                    0.03
# genero                                        0.02
# nse_colegio                                   0.01
# puntaje_ingles                                0.00
# percentil_global                              0.00
# internet                                      0.00
# consola                                       0.00
# nacionalidad                                  0.00
# etnia_estudiante                              0.00
# microndas                                     0.00
# tv                                            0.00
# lavadora                                      0.00
# computador                                    0.00
# moto                                          0.00
# carro                                         0.00
# colegio_genero                                0.00
# colegio_naturaleza                            0.00
# puntaje_lectura                               0.00
# percentil_lectura                             0.00
# colegio_calendario                            0.00
# colegio_caracter                              0.00
# colegio_area                                  0.00
# colegio_jornada                               0.00
# colegio_mpio                                  0.00
# colegio_dpto                                  0.00
# percentil_naturales                           0.00
# puntaje_naturales                             0.00
# nivel_matematicas                             0.00
# percentil_matematicas                         0.00
# puntaje_matematicas                           0.00
# nivel_lectura                                 0.00
# percentil_sociales                            0.00
# nivel_naturales                               0.00
# puntaje_global                                0.00
# nivel_ingles                                  0.00
# percentil_ingles                              0.00
# nivel_sociales                                0.00
# puntaje_sociales                              0.00
# edad                                          0.00
# presento_fuera_edad                           0.00
# region                                        0.00

# %%
# Análisis por fila
missing_per_row = icfes.isnull().sum(axis=1)
print(f"Filas sin missing: {(missing_per_row == 0).sum()}")
print(f"Filas con 1 missing: {(missing_per_row == 1).sum()}")
print(f"Filas con 2 missing: {(missing_per_row == 2).sum()}")
print(f"Filas con 1-2 missing: {((missing_per_row >= 1) & (missing_per_row <= 2)).sum()}")
print(f"Filas con 3 missing: {(missing_per_row == 3).sum()}")
print(f"Filas con 4 missing: {(missing_per_row == 4).sum()}")
print(f"Filas con 3-4 missing: {((missing_per_row >= 3) & (missing_per_row <= 4)).sum()}")
print(f"Filas con 5 missing: {(missing_per_row == 5).sum()}")
print(f"Filas con >5 missing: {(missing_per_row > 5).sum()}")
# Out:
# Filas sin missing: 419944
# Filas con 1 missing: 70321
# Filas con 2 missing: 12969
# Filas con 1-2 missing: 83290
# Filas con 3 missing: 2248
# Filas con 4 missing: 841
# Filas con 3-4 missing: 3089
# Filas con 5 missing: 594
# Filas con >5 missing: 36817

# %%
columnas_a_eliminar = ["grupo_edad", "genero"]

filas_antes = icfes.shape[0]

# Eliminar filas con NA en estas columnas
icfes = icfes.dropna(subset=columnas_a_eliminar)

# Mostrar la cantidad de filas restantes
print(f"Cantidad de filas antes de eliminar NA: {filas_antes}")
print("------------------------------------------------------")
print(f"Cantidad de filas después de eliminar NA: {icfes.shape[0]}")
print("------------------------------------------------------")
print(f"Filas eliminadas: {filas_antes - icfes.shape[0]}")
# Out:
# Cantidad de filas antes de eliminar NA: 543734
# ------------------------------------------------------
# Cantidad de filas después de eliminar NA: 543448
# ------------------------------------------------------
# Filas eliminadas: 286

# %%
# Información básica del dataset
total_columnas = icfes.shape[1]
print(f"Total de columnas en el dataset: {total_columnas}")
print("\n📊 CONVERSIÓN DE PORCENTAJES A NÚMEROS ABSOLUTOS")
print("=" * 60)

# Calcular cuántos NAs corresponden a cada porcentaje
porcentajes = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

for pct in porcentajes:
    num_nas = (pct / 100) * total_columnas
    num_nas_entero = int(num_nas)
    num_nas_redondeado = round(num_nas)
    
    print(f"{pct}% de NA = {num_nas:.1f} columnas ≈ {num_nas_redondeado} columnas")
# Out:
# Total de columnas en el dataset: 59
#
# 📊 CONVERSIÓN DE PORCENTAJES A NÚMEROS ABSOLUTOS
# ============================================================
# 5% de NA = 3.0 columnas ≈ 3 columnas
# 10% de NA = 5.9 columnas ≈ 6 columnas
# 15% de NA = 8.8 columnas ≈ 9 columnas
# 20% de NA = 11.8 columnas ≈ 12 columnas
# 25% de NA = 14.8 columnas ≈ 15 columnas
# 30% de NA = 17.7 columnas ≈ 18 columnas
# 35% de NA = 20.6 columnas ≈ 21 columnas
# 40% de NA = 23.6 columnas ≈ 24 columnas
# 45% de NA = 26.6 columnas ≈ 27 columnas
# 50% de NA = 29.5 columnas ≈ 30 columnas

# %%
# Contar NA por fila
na_por_fila = icfes.isna().sum(axis=1)

# Calcular el porcentaje de NA por fila
porcentaje_na_por_fila = (na_por_fila / icfes.shape[1]) * 100

# Información del dataset
total_columnas = icfes.shape[1]

# Calcular equivalencias en números absolutos
nas_10_pct = round((10 / 100) * total_columnas)
nas_20_pct = round((20 / 100) * total_columnas)
nas_25_pct = round((25 / 100) * total_columnas)

# Contar filas con más del 25% de NA
filas_con_mas_25_na = (porcentaje_na_por_fila > 25).sum()

# Estadísticas adicionales
na_promedio_por_fila = porcentaje_na_por_fila.mean()
nas_promedio_absoluto = round((na_promedio_por_fila / 100) * total_columnas)
indice_fila_max_na = na_por_fila.idxmax()
maximo_na = na_por_fila.max()
porcentaje_max_na = porcentaje_na_por_fila.max()

# Resultados con equivalencias
print(f"Dataset tiene {total_columnas} columnas totales")
print("-" * 50)
print(f"Hay {((porcentaje_na_por_fila >= 10) & (porcentaje_na_por_fila < 20)).sum()} filas entre el 10% y 20% de NA (entre {nas_10_pct} y {nas_20_pct-1} columnas faltantes)")
print(f"Hay {(porcentaje_na_por_fila == 20).sum()} filas con exactamente el 20% de NA (exactamente {nas_20_pct} columnas faltantes)")
print(f"Hay {filas_con_mas_25_na} filas con más del 25% de NA (más de {nas_25_pct} columnas faltantes)")
print(f"Promedio de NA por fila: {na_promedio_por_fila:.2f}% (≈ {nas_promedio_absoluto} columnas faltantes)")
print(f"La fila con más NA es la fila {indice_fila_max_na} con {maximo_na} valores NA ({porcentaje_max_na:.2f}%)")
# Out:
# Dataset tiene 59 columnas totales
# --------------------------------------------------
# Hay 27293 filas entre el 10% y 20% de NA (entre 6 y 11 columnas faltantes)
# Hay 0 filas con exactamente el 20% de NA (exactamente 12 columnas faltantes)
# Hay 8280 filas con más del 25% de NA (más de 15 columnas faltantes)
# Promedio de NA por fila: 1.62% (≈ 1 columnas faltantes)
# La fila con más NA es la fila 195819 con 20 valores NA (33.90%)

# %%
filas_antes = icfes.shape[0]

# 1. Contar los NA por fila
na_counts_per_row = icfes.isna().sum(axis=1)

# 2. Filtrar las filas con más de 5 NA
rows_to_drop = na_counts_per_row[na_counts_per_row >= 5].index

# 3. Eliminar las filas filtradas
icfes = icfes.drop(rows_to_drop)

print(f"Se eliminaron {len(rows_to_drop)} filas con más de 5 valores NA.")

# Mostrar la cantidad de filas restantes
print(f'Cantidad de filas antes de eliminar NA: {filas_antes}')
print(f"Cantidad de filas después de eliminar NA: {icfes.shape[0]}")
print(f"Filas eliminadas: {filas_antes - icfes.shape[0]}")
# Out:
# Se eliminaron 37391 filas con más de 5 valores NA.
# Cantidad de filas antes de eliminar NA: 543448
# Cantidad de filas después de eliminar NA: 506057
# Filas eliminadas: 37391

# %%
icfes.shape
# Out:
# (506057, 59)

# %%
icfes.columns
# Out:
# Index(['nacionalidad', 'genero', 'etnia_estudiante', 'estrato_casa',
#        'num_personas_casa', 'num_cuartos_casa', 'nivel_edu_padre',
#        'nivel_edu_madre', 'actividad_madre', 'actividad_padre', 'internet',
#        'tv', 'computador', 'lavadora', 'microndas', 'carro', 'moto', 'consola',
#        'num_libros', 'freq_leche_derivados', 'freq_carne_pescado_similares',
#        'freq_cereales_frutos_legumbres', 'situacion_economica_casa',
#        'tiempo_lectura', 'tiempo_internet', 'horas_trabajo_semanal',
#        'tipo_remuneracion', 'colegio_genero', 'colegio_naturaleza',
#        'colegio_calendario', 'colegio_caracter', 'colegio_area',
#        'colegio_jornada', 'colegio_mpio', 'colegio_dpto', 'puntaje_lectura',
#        'percentil_lectura', 'nivel_lectura', 'puntaje_matematicas',
#        'percentil_matematicas', 'nivel_matematicas', 'puntaje_naturales',
#        'percentil_naturales', 'nivel_naturales', 'puntaje_sociales',
#        'percentil_sociales', 'nivel_sociales', 'puntaje_ingles',
#        'percentil_ingles', 'nivel_ingles', 'puntaje_global',
#        'percentil_global', 'inse_estudiante', 'nse_estudiante', 'nse_colegio',
#        'edad', 'grupo_edad', 'presento_fuera_edad', 'region'],
#       dtype='object')

# %%
orden_variables = ['nacionalidad', 'genero', 'region', 'etnia_estudiante', 'edad', 'grupo_edad', 'presento_fuera_edad', 'num_personas_casa', 'num_cuartos_casa', 'estrato_casa',
                   'tiempo_internet', 'internet', 'tv', 'computador', 'lavadora', 'microndas', 'carro', 'moto', 'consola', 'situacion_economica_casa',
                   'num_libros', 'tiempo_lectura', 'freq_leche_derivados', 'freq_carne_pescado_similares', 'freq_cereales_frutos_legumbres',
                   'nivel_edu_padre', 'actividad_padre', 'nivel_edu_madre', 'actividad_madre', 'horas_trabajo_semanal', 'tipo_remuneracion',
                   'colegio_genero', 'colegio_naturaleza', 'colegio_calendario', 'colegio_caracter', 'colegio_area', 'colegio_jornada', 'colegio_mpio', 'colegio_dpto', 'puntaje_lectura',
                   'percentil_lectura', 'puntaje_matematicas', 'percentil_matematicas', 'nivel_matematicas', 'puntaje_naturales', 'percentil_naturales', 'nivel_naturales', 'puntaje_sociales', 
                   'percentil_sociales', 'nivel_sociales', 'puntaje_ingles', 'percentil_ingles', 'nivel_ingles', 'puntaje_global', 'percentil_global', 'inse_estudiante', 
                   'nse_estudiante', 'nse_colegio']

icfes = icfes[orden_variables]

# %%
# Guardar DataFrame en parquet
icfes.to_parquet("icfes_limpio.parquet", index=False, engine="pyarrow")
